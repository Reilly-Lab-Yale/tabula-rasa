# %% [markdown]
# This notebook imports & perform basic analysis of the shendure data using our package.

# %%
import sys
import os
package_path = os.path.abspath("../..")  
sys.path.insert(0, package_path)
#The path will be managed by conda or whatever on release, but this is fine for now.

import scMPRAforge as scm
data_root="/gpfs/gibbs/pi/reilly/tabula_data"

# %%
#load the autoreload extension
# %load_ext autoreload
#reload code on every execution
#(this may break objects)
#you can remove this & do dev in a notebook, then paste into the module when you are done.
# %autoreload 2

# %%
scm.helloworld()
# Out:
# hello world!

# %%
sh=scm.load_scMPRA_data(f"{data_root}/shendure/shendure_counts_grouped.txt")

# %%
sh
# Out:
#                        cell_bc rep_id  cre_class            cre_id  \
# 0       2B1_AAACCCACAAGGTTGG-1    2B1     devCRE   Btg1_chr10_9572
# 1       2B1_AAACCCACAAGGTTGG-1    2B1     devCRE  Gata4_chr14_5710
# 2       2B1_AAACCCACAAGGTTGG-1    2B1     devCRE    Klf4_chr4_3952
# 3       2B1_AAACCCACAAGGTTGG-1    2B1     devCRE  Lama1_chr17_7793
# 4       2B1_AAACCCACAAGGTTGG-1    2B1     devCRE     Sox17_chr1_67
# ...                        ...    ...        ...               ...
# 778243   B2_TTTGTTGGTGGACCAA-1     B2     devCRE  Sparc_chr11_7207
# 778244   B2_TTTGTTGGTGGACCAA-1     B2     devCRE  Tgfbi_chr13_5735
# 778245   B2_TTTGTTGGTGGACCAA-1     B2     devCRE  Tgfbi_chr13_5741
# 778246   B2_TTTGTTGGTGGACCAA-1     B2  promoters               noP
# 778247   B2_TTTGTTGGTGGACCAA-1     B2  promoters             pgk1P
#
#                  cell_type                     transfection_bc  \
# 0       NeuroectodermBrain                    CATCGCTGAGTAAACG
# 1       NeuroectodermBrain                    GAGGATGAGTTGGAAT
# 2       NeuroectodermBrain                    CGTGAATTAATTCTAT
# 3       NeuroectodermBrain                    AGTAAGTCAGCTCTTT
# 4       NeuroectodermBrain                    GACAATAAAATTCCAT
# ...                    ...                                 ...
# 778243  ExEndodermVisceral                    AATAATCACTCAAATT
# 778244  ExEndodermVisceral                    AGTCCATGGAGGGAGG
# 778245  ExEndodermVisceral                    CTCAAGTTAGTAAGGG
# 778246  ExEndodermVisceral  ACTTCTCGCCAAGGAA, GTTTCTTCGTCTGCCC
# 778247  ExEndodermVisceral                    CGATCAATGACCATTC
#
#                                  mpra_bc  reads_transfection_bc  \
# 0                        GCGTACTCACCAGGT                     73
# 1                        CAATCGCACCCCCGA                    167
# 2                        AACCCGGTAAATGTA                     99
# 3                        CGTGACCTCTTCATT                    159
# 4                        ACAGTCACAAATTTA                     59
# ...                                  ...                    ...
# 778243                   TACCAACTGAGACAT                    130
# 778244                   GTTTACCACATTACT                    108
# 778245                   CAGGGAACTGCCACC                     75
# 778246  TCCCGCTGACACTTA, ATGTGGGTCGTCTAT                    200
# 778247                   TGGATAGCACAAATA                     88
#
#         umis_transfection_bc  reads_mpra_bc  umis_mpra_bc
# 0                         67              0             0
# 1                        159              0             0
# 2                         89              0             0
# 3                        147              0             0
# 4                         58              0             0
# ...                      ...            ...           ...
# 778243                   104              0             0
# 778244                    98              0             0
# 778245                    68             19             1
# 778246                   166              0             0
# 778247                    77              8             1
#
# [778248 rows x 11 columns]

# %%
sh_model=scm.experiment_model(sh,'tfection_umi')

# %%
sh_model.fit()
# Out:
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:4329: RuntimeWarning: overflow encountered in exp
#   return np.exp(linpred)
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3937: RuntimeWarning: invalid value encountered in multiply
#   a1 * np.log(a1) + y * np.log(mu) -
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3936: RuntimeWarning: invalid value encountered in subtract
#   llf = (gammaln(y + a1) - gammaln(y + 1) - gammaln(a1) +
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3974: RuntimeWarning: divide by zero encountered in log
#   dgterm = dgpart + np.log(a1 / a2) + 1 - a3 / a2
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3977: RuntimeWarning: invalid value encountered in multiply
#   dparams = (a4 * dgterm -
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: overflow encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3980: RuntimeWarning: invalid value encountered in multiply
#   dparams = (self.exog.T * mu * dparams).T
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/count_model.py:269: RuntimeWarning: invalid value encountered in multiply
#   dldp[zero_idx,:] = (score_main[zero_idx].T *
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1313: OptimizeWarning: NaN result encountered.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#          Current function value: nan
#          Iterations: 0
#          Function evaluations: 1
#          Gradient evaluations: 1
# /home/mcn26/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/count_model.py:324: RuntimeWarning: invalid value encountered in multiply
#   hess_arr[i, j + self.k_inflate] = -(score_main[zero_idx, j] *

# %%
dir(sh_model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'fit',
#  'formula',
#  'formula_type',
#  'from_pickle',
#  'round_down_threshold',
#  'scmpra_data',
#  'to_pickle',
#  'valid_formula_types']
