# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.discrete.count_model as smdc
import seaborn as sns
import matplotlib.pyplot as plt
import patsy

# %%
fake_cres=pd.read_csv("fake_cres.csv").drop("Unnamed: 0",axis=1)

# %%
fake_cres
# Out:
#              CRE Cell_type  replicate_ID  umi_count
# 0         nobody     brain             1          0
# 1         nobody     brain             1          0
# 2         nobody     brain             1          0
# 3         nobody     brain             1          0
# 4         nobody     brain             1          0
# ...          ...       ...           ...        ...
# 14307  neurogene     blood             3          7
# 14308  neurogene     blood             3         26
# 14309  neurogene     blood             3          7
# 14310  neurogene     blood             3         15
# 14311  neurogene     blood             3         38
#
# [14312 rows x 4 columns]

# %%
fake_cres_munged=fake_cres
fake_cres_munged["replicate_ID"]=fake_cres_munged["replicate_ID"].map({1:"rep1",2:"rep2",3:"rep3"})

# %% [markdown]
# Some of these are strings or ints when they should be categorical...
#
# We can either cast to categorical in the dataframe, or specify that the values should be categorical in the formula (for items in the formula) or one-hot with `pd.dummies` for the statsmodels interface.

# %% [markdown]
# A couple different ways of stipulating the model.
# - String formula can't use the pipe operator to pass a second formula

# %%
fake_cres_munged
# Out:
#              CRE Cell_type replicate_ID  umi_count
# 0         nobody     brain         rep1          0
# 1         nobody     brain         rep1          0
# 2         nobody     brain         rep1          0
# 3         nobody     brain         rep1          0
# 4         nobody     brain         rep1          0
# ...          ...       ...          ...        ...
# 14307  neurogene     blood         rep3          7
# 14308  neurogene     blood         rep3         26
# 14309  neurogene     blood         rep3          7
# 14310  neurogene     blood         rep3         15
# 14311  neurogene     blood         rep3         38
#
# [14312 rows x 4 columns]

# %%
y, X = patsy.dmatrices("umi_count ~ C(CRE)*C(Cell_type)-1",
                        fake_cres_munged, return_type='dataframe')
Z = patsy.dmatrix("C(replicate_ID)", fake_cres_munged, return_type='dataframe')

zinb_model = smdc.ZeroInflatedNegativeBinomialP(y, X, exog_infl=Z)

n_count_params = zinb_model.exog.shape[1]      # Count model parameters
n_infl_params = zinb_model.exog_infl.shape[1]    # Inflation model parameters
n_total = n_count_params + n_infl_params + 1 # adding 1 for alpha
start_params = np.full(n_total, 0.1)

zinb_result = zinb_model.fit(start_params=start_params,maxiter=1000)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.483284
#          Iterations: 84
#          Function evaluations: 85
#          Gradient evaluations: 85

# %% [markdown]
# https://stats.stackexchange.com/questions/284911/type-i-and-type-ii-negative-binomial-distribution-in-zero-inflated-negative-bino

# %% [markdown]
# https://www.statsmodels.org/stable/generated/statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialP.html
#
# https://www.statsmodels.org/dev/generated/statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialP.from_formula.html#statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialP.from_formula

# %%
print(type(zinb_result))
zinb_result.summary()
# Out:
# <class 'statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialResultsWrapper'>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      ZeroInflatedNegativeBinomialP Regression Results
# ...
# Dep. Variable:                         umi_count   No. Observations:                14312
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                    14302
# Method:                                      MLE   Df Model:                            9
# Date:                           Wed, 09 Apr 2025   Pseudo R-squ.:                  0.1598
# Time:                                   17:39:44   Log-Likelihood:                -21229.
# converged:                                  True   LL-Null:                       -25265.
# Covariance Type:                       nonrobust   LLR p-value:                     0.000
# ...
#                                                 coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# # Recapitulation of $\theta$ (constant in mean-variance quadratic)
#
# First, let's examine theta. That is, the theta in $\sigma^2=\mu+\mu^2/\theta$.
#
# From our generation step, we know the true $\theta$ value to be 0.3.
#
# Statsmodels seems to call it alpha, but regardless, it's quite close to the real value.

# %%
zinb_result.params["alpha"]
# Out:
# np.float64(0.2867779982959691)

# %% [markdown]
# # Recapitulating $\mu$ values

# %%
#we begin by getting all combinations of the predictors (which are of course all categorical) present in the data. 
minimal_nb_design = X.drop_duplicates()
minimal_nb_design
# Out:
#       C(CRE)[everybody]  C(CRE)[neurogene]  C(CRE)[nobody]  C(CRE)[redgene]  \
# 0                   0.0                0.0             1.0              0.0
# 440                 0.0                0.0             0.0              0.0
# 904                 1.0                0.0             0.0              0.0
# 1355                0.0                0.0             0.0              1.0
# 1798                0.0                1.0             0.0              0.0
# 2263                0.0                0.0             1.0              0.0
# 2762                0.0                0.0             0.0              0.0
# 3266                1.0                0.0             0.0              0.0
# 3767                0.0                0.0             0.0              1.0
# 4262                0.0                1.0             0.0              0.0
#
#       C(CRE)[somebody]  C(Cell_type)[T.brain]  \
# 0                  0.0                    1.0
# ...

# %%
#let's look at our paramaters (fitted betas)
zinb_result.params
# Out:
# inflate_Intercept                            1.355423
# inflate_C(replicate_ID)[T.rep2]             -1.327281
# inflate_C(replicate_ID)[T.rep3]              0.888705
# C(CRE)[everybody]                            4.639833
# C(CRE)[neurogene]                            2.740756
# C(CRE)[nobody]                               0.665935
# C(CRE)[redgene]                              4.659436
# C(CRE)[somebody]                             2.525434
# C(Cell_type)[T.brain]                        0.039876
# C(CRE)[T.neurogene]:C(Cell_type)[T.brain]    1.786778
# C(CRE)[T.nobody]:C(Cell_type)[T.brain]      -0.679159
# C(CRE)[T.redgene]:C(Cell_type)[T.brain]     -1.273865
# C(CRE)[T.somebody]:C(Cell_type)[T.brain]    -0.263831
# alpha                                        0.286778
# dtype: float64

# %%
#extract the inflation parameters into one variable (for later use)
#and the negative-binomial parameters into a different variable (for immediate use)
inflation_betas=zinb_result.params[0:n_infl_params]
nb_betas=zinb_result.params[n_infl_params:n_count_params + n_infl_params]
#possibly a more robust way of doing this would be on the basis of names
#So long as none of the nb predictors have "inflate" in their names...

# %%
#make sure they are in the same order...
all(nb_betas.keys()==minimal_nb_design.columns)
# Out:
# True

# %%
#get the linear version of the predictors with a dot-product
linear_predictors=minimal_nb_design.dot(nb_betas)
#undo the log-link
expected_values=np.exp(linear_predictors)

# %%
#make and display a little dataframe.
#hard-coding the names for this demo, we could easially un-one-hot 
#or make the minimal_nb_design mat from scratch for more complicated cases
recapitulated_nb_rate=pd.DataFrame({"cre":["nobody","somebody","everybody","redgene","neurogene","nobody","somebody","everybody","redgene","neurogene"],
    "cell_type":["brain"]*5+["blood"]*5,
    "expected_rate":expected_values})
recapitulated_nb_rate
# Out:
#             cre cell_type  expected_rate
# 0        nobody     brain       1.027010
# 440    somebody     brain       9.988947
# 904   everybody     brain     107.738697
# 1355    redgene     brain      30.736365
# 1798  neurogene     brain      96.294471
# 2263     nobody     blood       1.946309
# 2762   somebody     blood      12.496317
# 3266  everybody     blood     103.527025
# 3767    redgene     blood     105.576498
# 4262  neurogene     blood      15.498705

# %% [markdown]
# Comparing to real data...

# %%
REAL_data = {
    "CRE": ["nobody", "somebody", "everybody", "redgene", "neurogene", "nobody", "somebody", "everybody", "redgene", "neurogene"],
    "Cell-type": ["brain", "brain", "brain", "brain", "brain", "blood", "blood", "blood", "blood", "blood"],
    "mean": [1, 10, 114, 30, 99, 2, 12, 109, 112, 16]
}

# Creating the dataframe
pd.DataFrame(REAL_data)
# Out:
#          CRE Cell-type  mean
# 0     nobody     brain     1
# 1   somebody     brain    10
# 2  everybody     brain   114
# 3    redgene     brain    30
# 4  neurogene     brain    99
# 5     nobody     blood     2
# 6   somebody     blood    12
# 7  everybody     blood   109
# 8    redgene     blood   112
# 9  neurogene     blood    16

# %% [markdown]
# Works very well.

# %% [markdown]
# # Recapitulation of zero-inflation parameter

# %%
minimal_dropout_design=Z.drop_duplicates()
minimal_dropout_design
# Out:
#       Intercept  C(replicate_ID)[T.rep2]  C(replicate_ID)[T.rep3]
# 0           1.0                      0.0                      0.0
# 4761        1.0                      1.0                      0.0
# 9536        1.0                      0.0                      1.0

# %%
linear_dropout_pred=minimal_dropout_design.to_numpy() @ inflation_betas
linear_dropout_pred
# Out:
# array([1.35542266, 0.02814137, 2.24412758])

# %%
recovered_dropout=1/(1+np.exp(-linear_dropout_pred))
#top to bottom in the matrix are : intercept only (rep1 by process of elim), rep2, rep3
pd.DataFrame({'replicate':["rep1","rep2","rep3"],'dropout':recovered_dropout})
# Out:
#   replicate   dropout
# 0      rep1  0.795015
# 1      rep2  0.507035
# 2      rep3  0.904143

# %% [markdown]
# Compared to real values (.8, .5, .9), that's pretty good!

# %% [markdown]
# # Checking non zero inflated

# %%
import statsmodels.discrete.discrete_model as smd
nb_model = smd.NegativeBinomial(y, X)
nb_results = nb_model.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.742087
#          Iterations: 5
#          Function evaluations: 7
#          Gradient evaluations: 7

# %%
nb_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      NegativeBinomial Regression Results
# ...
# Dep. Variable:              umi_count   No. Observations:                14312
# Model:               NegativeBinomial   Df Residuals:                    14302
# Method:                           MLE   Df Model:                            9
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                 0.02837
# Time:                        17:39:45   Log-Likelihood:                -24933.
# converged:                       True   LL-Null:                       -25661.
# Covariance Type:            nonrobust   LLR p-value:                5.483e-308
# ...
#                                                 coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # eriniform frequency diagrams
# Let's take a look at erin-style frequency histograms of the total data...

# %%
nb_results.predict()
# Out:
# array([0.2847432 , 0.2847432 , 0.2847432 , ..., 4.05337838, 4.05337838,
#        4.05337838])

# %%
comparison_df=pd.DataFrame({
    "interaction_term_zinb":zinb_result.predict(),
    "interaction_term_nb":nb_results.predict(),
    "real_data":fake_cres_munged["umi_count"]
})

sns.histplot(
    comparison_df
)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(comparison_df["interaction_term_zinb"])
# Out:
# <Axes: xlabel='interaction_term_zinb', ylabel='Count'>

# %% [markdown]
# It seems clear to me that these are not comparable at all. This is despite the fact that we know that at least one of the models (interaction term zinb) works great : it recovers the real parameters we put in. I believe `.predict()` is just returning the predicted $\mu$ for each linear combo. Let's check that...

# %%
verification=fake_cres_munged.copy()
verification["prediction"]=zinb_result.predict()
verification.drop(["umi_count"],axis=1,inplace=True)
verification.drop_duplicates(inplace=True)
verification
# Out:
#              CRE Cell_type replicate_ID  prediction
# 0         nobody     brain         rep1    0.210522
# 440     somebody     brain         rep1    2.047587
# 904    everybody     brain         rep1   22.084844
# 1355     redgene     brain         rep1    6.300501
# 1798   neurogene     brain         rep1   19.738946
# 2263      nobody     blood         rep1    0.398965
# 2762    somebody     blood         rep1    2.561561
# 3266   everybody     blood         rep1   21.221513
# 3767     redgene     blood         rep1   21.641624
# 4262   neurogene     blood         rep1    3.177006
# 4761      nobody     brain         rep2    0.506280
# 5204    somebody     brain         rep2    4.924202
# 5638   everybody     brain         rep2   53.111420
# 6103     redgene     brain         rep2   15.151956
# 6568   neurogene     brain         rep2   47.469816
# 7028      nobody     blood         rep2    0.959462
# 7531    somebody     blood         rep2    6.160248
# ...

# %% [markdown]
# Very interesting that there are different vals for different repid, given that the NB portion was not regressed on rep ID. Must mean that the means are not $\mu$ of just NB portion, but $\mu$ of the whole thing considered together (NB & Z).

# %%
verification[verification["Cell_type"]=="brain"][verification["CRE"]=="everybody"]
# Out:
# /tmp/tmp.NWByfmsMMO/ipykernel_2520682/3056891269.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   verification[verification["Cell_type"]=="brain"][verification["CRE"]=="everybody"]
#              CRE Cell_type replicate_ID  prediction
# 904    everybody     brain         rep1   22.084844
# 5638   everybody     brain         rep2   53.111420
# 10434  everybody     brain         rep3   10.327531

# %% [markdown]
# Recall that the true dropout values are .8 .5 .9 for rep 1, 2, 3, respectively. Higher dropout would naturally mean a lower mean, which is what we see above.
#
# If we're correct about what these represent, then we could predict the values as $\mu_{nb} \cdot (1-\pi)$ (of the ground truth). (To derive : imaging the drawing process. for $\pi=.8$  80% of the time it will draw 0, and the other 20% of the time we sample a distro with a mean of $\mu_{nb}$ : for n draws average will be
#
# $(\sum_1^{n\cdot\pi} 0+\sum_1^{n\cdot(1-\pi)}\mu_{nb})/n$
#
# $(\sum_1^{n\cdot(1-\pi)}\mu_{nb})/n$
#
# $(n\cdot(1-\pi)\cdot\mu_{nb})/n$
#
# $\mu_{nb} \cdot (1-\pi)$
#
# OK, let's do that. everybody/brain has a true mean of 114.
#
# - rep1: $114 \cdot (1-0.8)=22.8$
#   - $(22.8-22.084844)/22.8*100=3.14\%$ difference
# - rep2: $114 \cdot (1-0.5)=57$
#   - $(57-53.111420)/57*100=6.82\%$ difference
# - rep3: $114 \cdot (1-0.9)=11.4$
#   - $(11.4-10.327531)/11.4*100=9.41\%$ difference
#
# Yeah these are pretty close.

# %% [markdown]
# This also totally explains why the two plots are not really comparable : suppose conditions A, B, C parametrize dA, dB, dC (d for distro), each of which are sampled sA sB, sC times. `.predict()` will produce a vector composed of "(mean(dA) sA times)&(mean(dB) sB times)&(mean(dC) sC times)" : which is not the same at all as the original data, which is "(sA draws from dA)&(sB draws from dB)&(sC draws from dC)" (Though the means will be similar!).
#
# How can we make plots that *are* comparable? Maybe rvs? Or some function which directly returns a PDF? Or some hack which produces such a PDF?
#
# Let's investigate rvs.

# %%
len(zinb_result.get_distribution().rvs())==len(fake_cres_munged)
# Out:
# True

# %%
len(fake_cres_munged)
# Out:
# 14312

# %%
verification_rvs=fake_cres_munged.copy()
verification_rvs["rvs"]=zinb_result.get_distribution().rvs(random_state=42)
verification_rvs.drop(["umi_count"],axis=1,inplace=True)
verification_rvs.drop_duplicates(inplace=True)
verification_rvs
# Out:
#              CRE Cell_type replicate_ID  rvs
# 0         nobody     brain         rep1    0
# 1         nobody     brain         rep1    2
# 43        nobody     brain         rep1    1
# 69        nobody     brain         rep1    3
# 440     somebody     brain         rep1    0
# ...          ...       ...          ...  ...
# 14093  neurogene     blood         rep3   18
# 14118  neurogene     blood         rep3   25
# 14236  neurogene     blood         rep3   11
# 14249  neurogene     blood         rep3   33
# 14257  neurogene     blood         rep3   13
#
# [1467 rows x 4 columns]

# %% [markdown]
# Ah ok. I see what it is doing. It is generating random preds for each row / combo! If you run the cell above multiple times (with different seeds), you'll get DFs w/ different lengths, as the reducton in removing duplicate rows is just removing the same pred occuring multiple times... To make a distro comparable to the real data then, we'd either compare this directly, or run sampling many times & average... Let's try the former first...

# %%
comparison_df["rvs"]=zinb_result.get_distribution().rvs()

# %%
sns.histplot(comparison_df[["real_data","rvs"]],element='step', linestyle=':')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Ok, that's annoying to look at, let's just do a side-by-side.

# %%
sns.histplot(comparison_df[["real_data"]])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(comparison_df[["rvs"]])
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Yeah they look pretty much the same. Let's examine the difference numerically...

# %%
_,counts_rvs=np.unique(comparison_df["rvs"], return_counts=True)
_,counts_real=np.unique(comparison_df["real_data"], return_counts=True)

# %% [markdown]
# Can we just directly subtract?

# %%
len(counts_real)==len(counts_rvs)
# Out:
# False

# %% [markdown]
# No, there is a different max number for one of them (real or simulated) so the counts vector is a different length. Let's pad the shorter one with zeroes (since a missing max would be a zero frequency)...

# %%
len(counts_real)
# Out:
# 245

# %%
len(counts_rvs)
# Out:
# 258

# %% [markdown]
# Ok, real is shorter (for a seet of 42) by 258-245=13.

# %%
counts_real = np.concatenate([counts_real, np.zeros(13)])

# %%
len(counts_real)==len(counts_rvs)
# Out:
# True

# %%
error=(counts_real-counts_rvs)/counts_real*100
error
# Out:
# /tmp/tmp.NWByfmsMMO/ipykernel_2520682/516156852.py:1: RuntimeWarning: divide by zero encountered in divide
#   error=(counts_real-counts_rvs)/counts_real*100
# array([ 4.64856824e-02,  1.48854962e+01,  1.75257732e+01, -3.58695652e+01,
#        -2.18390805e+01,  3.15789474e+00, -5.39682540e+01, -5.86206897e+01,
#        -9.45945946e+00,  0.00000000e+00, -2.81690141e+00,  1.15942029e+01,
#         2.79569892e+01,  4.60317460e+01, -3.95348837e+01, -8.19672131e+00,
#        -1.16279070e+01,  0.00000000e+00, -4.35897436e+01, -2.32558140e+00,
#        -1.56250000e+01,  1.11111111e+01,  1.77777778e+01,  3.42857143e+01,
#        -1.11111111e+01,  2.36842105e+01,  3.17073171e+01,  2.75862069e+01,
#        -2.22222222e+01, -3.33333333e+01, -2.50000000e+01,  1.05263158e+01,
#        -4.44444444e+01,  1.11111111e+01,  3.33333333e+01,  4.44444444e+01,
#        -2.30769231e+01,  5.20000000e+01, -3.33333333e+01,  1.36363636e+01,
# ...

# %%
sns.lineplot(error)
# Out:
# <Axes: >

# %% [markdown]
# So generally error seems pretty low, but a few specific points it's pretty bad... Specifically at lower-count high numbers. If we smooth

# %%
sum(counts_real[100:])/sum(counts_real)*100
# Out:
# np.float64(4.8420905533817775)

# %% [markdown]
# We could so some fancy windowing, etc... but only 5% of the data is above umi count of 100... Why don't we just calculate median error...

# %%
np.median(error)
# Out:
# np.float64(0.0)

# %%
np.mean(error[np.isfinite(error)])
# Out:
# np.float64(-26.89970396290281)

# %% [markdown]
# Next question: erin has had trouble w/ ±ZI returning the same rvs.. Let's see if I can reproduce that.

# %%
comparison_df["rvs_nb_no_z"]=nb_results.get_distribution().rvs(random_state=42)

# %%
sns.histplot(comparison_df[["real_data","rvs_nb_no_z"]],element='step', linestyle=':')
# Out:
# <Axes: ylabel='Count'>

# %%
temp=comparison_df[["real_data","rvs_nb_no_z","rvs"]].melt(var_name="source", value_name="value")
sns.histplot(data=temp, x="value", hue="source", binrange=(0, 100), multiple="dodge")
# Out:
# <Axes: xlabel='value', ylabel='Count'>

# %% [markdown]
# No, I can't reproduce it : rsv looks good.
#
# How interesting that without zero-inflation it OVER estimates zeroes, probably by pulling the rate parameter too low...

# %%
_,counts_rvs_nb_no_z=np.unique(comparison_df["rvs_nb_no_z"], return_counts=True)

# %%
len(counts_rvs_nb_no_z)
# Out:
# 374

# %% [markdown]
# Interestingly, NB alone is also bad on the other end, away from the zeroes, as it predicts too many high counts...

# %%
len(counts_rvs_nb_no_z[0:len(counts_real)])==len(counts_real)
# Out:
# True

# %%
error_no_z=(counts_real-counts_rvs_nb_no_z[0:len(counts_real)])/counts_real*100
#truncating like this instead of padding is maybe a better idea since it avoids divide-by-zero...
# Out:
# /tmp/tmp.NWByfmsMMO/ipykernel_2520682/2763191501.py:1: RuntimeWarning: divide by zero encountered in divide
#   error_no_z=(counts_real-counts_rvs_nb_no_z[0:len(counts_real)])/counts_real*100

# %%
sns.lineplot(pd.DataFrame({"error_no_z":error_no_z,"error_with_z":error}))
# Out:
# <Axes: >

# %%
np.median(error_no_z)
# Out:
# np.float64(36.36363636363637)

# %% [markdown]
# # checking rvs against manual param draw...

# %% [markdown]
# I think that rsv is not explicitly supported for zinb so... Let's check against our own strat (pulling out the params & drawing...)

# %% [markdown]
# # A different way of evaluating
#
# Summarizing across all CREs *then* calculating error doesn't really make sense. Rather, we should calc error for each of what we expect to actually be a different ZINB graph (that is, each unique combination of linear predictors)
