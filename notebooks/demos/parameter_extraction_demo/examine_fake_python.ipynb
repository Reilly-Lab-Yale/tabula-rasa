# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.discrete.count_model as smdc
import patsy

# %%
fake_cres=pd.read_csv("fake_cres.csv").drop("Unnamed: 0",axis=1)

# %%
fake_cres
# Out:
#              CRE Cell_type  replicate_ID  umi_count
# 0         nobody     brain             1          0
# 1         nobody     brain             1          0
# 2         nobody     brain             1          0
# 3         nobody     brain             1          0
# 4         nobody     brain             1          0
# ...          ...       ...           ...        ...
# 14307  neurogene     blood             3          7
# 14308  neurogene     blood             3         26
# 14309  neurogene     blood             3          7
# 14310  neurogene     blood             3         15
# 14311  neurogene     blood             3         38
#
# [14312 rows x 4 columns]

# %%
fake_cres_munged=fake_cres
fake_cres_munged["replicate_ID"]=fake_cres_munged["replicate_ID"].map({1:"rep1",2:"rep2",3:"rep3"})

# %% [markdown]
# Some of these are strings or ints when they should be categorical...
#
# We can either cast to categorical in the dataframe, or specify that the values should be categorical in the formula (for items in the formula) or one-hot with `pd.dummies` for the statsmodels interface.

# %% [markdown]
# A couple different ways of stipulating the model.
# - String formula can't use the pipe operator to pass a second formula

# %%
fake_cres_munged
# Out:
#              CRE Cell_type replicate_ID  umi_count
# 0         nobody     brain         rep1          0
# 1         nobody     brain         rep1          0
# 2         nobody     brain         rep1          0
# 3         nobody     brain         rep1          0
# 4         nobody     brain         rep1          0
# ...          ...       ...          ...        ...
# 14307  neurogene     blood         rep3          7
# 14308  neurogene     blood         rep3         26
# 14309  neurogene     blood         rep3          7
# 14310  neurogene     blood         rep3         15
# 14311  neurogene     blood         rep3         38
#
# [14312 rows x 4 columns]

# %%
y, X = patsy.dmatrices("umi_count ~ C(CRE)*C(Cell_type)-1",
                        fake_cres_munged, return_type='dataframe')
Z = patsy.dmatrix("C(replicate_ID)", fake_cres_munged, return_type='dataframe')

zinb_model = smdc.ZeroInflatedNegativeBinomialP(y, X, exog_infl=Z)

n_count_params = zinb_model.exog.shape[1]      # Count model parameters
n_infl_params = zinb_model.exog_infl.shape[1]    # Inflation model parameters
n_total = n_count_params + n_infl_params + 1 # adding 1 for alpha
start_params = np.full(n_total, 0.1)

zinb_result = zinb_model.fit(start_params=start_params,maxiter=1000)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.483284
#          Iterations: 84
#          Function evaluations: 85
#          Gradient evaluations: 85

# %% [markdown]
# https://stats.stackexchange.com/questions/284911/type-i-and-type-ii-negative-binomial-distribution-in-zero-inflated-negative-bino

# %% [markdown]
# https://www.statsmodels.org/stable/generated/statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialP.html
#
# https://www.statsmodels.org/dev/generated/statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialP.from_formula.html#statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialP.from_formula

# %%
print(type(zinb_result))
zinb_result.summary()
# Out:
# <class 'statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialResultsWrapper'>
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:                         umi_count   No. Observations:                14312
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                    14302
# Method:                                      MLE   Df Model:                            9
# Date:                           Mon, 24 Feb 2025   Pseudo R-squ.:                  0.1598
# Time:                                   14:17:24   Log-Likelihood:                -21229.
# converged:                                  True   LL-Null:                       -25265.
# Covariance Type:                       nonrobust   LLR p-value:                     0.000
# =============================================================================================================
#                                                 coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# inflate_Intercept                             1.3554      0.037     36.249      0.000       1.282       1.429
# inflate_C(replicate_ID)[T.rep2]              -1.3273      0.048    -27.603      0.000      -1.422      -1.233
# inflate_C(replicate_ID)[T.rep3]               0.8887      0.063     14.102      0.000       0.765       1.012
# C(CRE)[everybody]                             4.6398      0.028    167.429      0.000       4.586       4.694
# C(CRE)[neurogene]                             2.7408      0.030     90.617      0.000       2.681       2.800
# C(CRE)[nobody]                                0.6659      0.052     12.869      0.000       0.565       0.767
# C(CRE)[redgene]                               4.6594      0.027    171.854      0.000       4.606       4.713
# C(CRE)[somebody]                              2.5254      0.030     82.913      0.000       2.466       2.585
# C(Cell_type)[T.brain]                         0.0399      0.040      0.999      0.318      -0.038       0.118
# C(CRE)[T.neurogene]:C(Cell_type)[T.brain]     1.7868      0.057     31.104      0.000       1.674       1.899
# C(CRE)[T.nobody]:C(Cell_type)[T.brain]       -0.6792      0.094     -7.252      0.000      -0.863      -0.496
# C(CRE)[T.redgene]:C(Cell_type)[T.brain]      -1.2739      0.056    -22.549      0.000      -1.385      -1.163
# C(CRE)[T.somebody]:C(Cell_type)[T.brain]     -0.2638      0.061     -4.352      0.000      -0.383      -0.145
# alpha                                         0.2868      0.008     35.107      0.000       0.271       0.303
# =============================================================================================================
# """

# %% [markdown]
# # Recapitulation of $\theta$ (constant in mean-variance quadratic)
#
# First, let's examine theta. That is, the theta in $\sigma^2=\mu+\mu^2/\theta$.
#
# From our generation step, we know the true $\theta$ value to be 0.3.
#
# Statsmodels seems to call it alpha, but regardless, it's quite close to the real value.

# %%
zinb_result.params["alpha"]
# Out:
# np.float64(0.2867779982959691)

# %% [markdown]
# # Recapitulating $\mu$ values

# %%
#we begin by getting all combinations of the predictors (which are of course all categorical) present in the data. 
minimal_nb_design = X.drop_duplicates()
minimal_nb_design
# Out:
#       C(CRE)[everybody]  C(CRE)[neurogene]  C(CRE)[nobody]  C(CRE)[redgene]  \
# 0                   0.0                0.0             1.0              0.0
# 440                 0.0                0.0             0.0              0.0
# 904                 1.0                0.0             0.0              0.0
# 1355                0.0                0.0             0.0              1.0
# 1798                0.0                1.0             0.0              0.0
# 2263                0.0                0.0             1.0              0.0
# 2762                0.0                0.0             0.0              0.0
# 3266                1.0                0.0             0.0              0.0
# 3767                0.0                0.0             0.0              1.0
# 4262                0.0                1.0             0.0              0.0
#
#       C(CRE)[somebody]  C(Cell_type)[T.brain]  \
# 0                  0.0                    1.0
# 440                1.0                    1.0
# 904                0.0                    1.0
# 1355               0.0                    1.0
# 1798               0.0                    1.0
# 2263               0.0                    0.0
# 2762               1.0                    0.0
# 3266               0.0                    0.0
# 3767               0.0                    0.0
# 4262               0.0                    0.0
#
#       C(CRE)[T.neurogene]:C(Cell_type)[T.brain]  \
# 0                                           0.0
# 440                                         0.0
# 904                                         0.0
# 1355                                        0.0
# 1798                                        1.0
# 2263                                        0.0
# 2762                                        0.0
# 3266                                        0.0
# 3767                                        0.0
# 4262                                        0.0
#
#       C(CRE)[T.nobody]:C(Cell_type)[T.brain]  \
# 0                                        1.0
# 440                                      0.0
# 904                                      0.0
# 1355                                     0.0
# 1798                                     0.0
# 2263                                     0.0
# 2762                                     0.0
# 3266                                     0.0
# 3767                                     0.0
# 4262                                     0.0
#
#       C(CRE)[T.redgene]:C(Cell_type)[T.brain]  \
# 0                                         0.0
# 440                                       0.0
# 904                                       0.0
# 1355                                      1.0
# 1798                                      0.0
# 2263                                      0.0
# 2762                                      0.0
# 3266                                      0.0
# 3767                                      0.0
# 4262                                      0.0
#
#       C(CRE)[T.somebody]:C(Cell_type)[T.brain]
# 0                                          0.0
# 440                                        1.0
# 904                                        0.0
# 1355                                       0.0
# 1798                                       0.0
# 2263                                       0.0
# 2762                                       0.0
# 3266                                       0.0
# 3767                                       0.0
# 4262                                       0.0

# %%
#let's look at our paramaters (fitted betas)
zinb_result.params
# Out:
# inflate_Intercept                            1.355423
# inflate_C(replicate_ID)[T.rep2]             -1.327281
# inflate_C(replicate_ID)[T.rep3]              0.888705
# C(CRE)[everybody]                            4.639833
# C(CRE)[neurogene]                            2.740756
# C(CRE)[nobody]                               0.665935
# C(CRE)[redgene]                              4.659436
# C(CRE)[somebody]                             2.525434
# C(Cell_type)[T.brain]                        0.039876
# C(CRE)[T.neurogene]:C(Cell_type)[T.brain]    1.786778
# C(CRE)[T.nobody]:C(Cell_type)[T.brain]      -0.679159
# C(CRE)[T.redgene]:C(Cell_type)[T.brain]     -1.273865
# C(CRE)[T.somebody]:C(Cell_type)[T.brain]    -0.263831
# alpha                                        0.286778
# dtype: float64

# %%
#extract the inflation parameters into one variable (for later use)
#and the negative-binomial parameters into a different variable (for immediate use)
inflation_betas=zinb_result.params[0:n_infl_params]
nb_betas=zinb_result.params[n_infl_params:n_count_params + n_infl_params]
#possibly a more robust way of doing this would be on the basis of names
#So long as none of the nb predictors have "inflate" in their names...

# %%
#make sure they are in the same order...
all(nb_betas.keys()==minimal_nb_design.columns)
# Out:
# True

# %%
#get the linear version of the predictors with a dot-product
linear_predictors=minimal_nb_design.dot(nb_betas)
#undo the log-link
expected_values=np.exp(linear_predictors)

# %%
#make and display a little dataframe.
#hard-coding the names for this demo, we could easially un-one-hot 
#or make the minimal_nb_design mat from scratch for more complicated cases
recapitulated_nb_rate=pd.DataFrame({"cre":["nobody","somebody","everybody","redgene","neurogene","nobody","somebody","everybody","redgene","neurogene"],
    "cell_type":["brain"]*5+["blood"]*5,
    "expected_rate":expected_values})
recapitulated_nb_rate
# Out:
#             cre cell_type  expected_rate
# 0        nobody     brain       1.027010
# 440    somebody     brain       9.988947
# 904   everybody     brain     107.738697
# 1355    redgene     brain      30.736365
# 1798  neurogene     brain      96.294471
# 2263     nobody     blood       1.946309
# 2762   somebody     blood      12.496317
# 3266  everybody     blood     103.527025
# 3767    redgene     blood     105.576498
# 4262  neurogene     blood      15.498705

# %% [markdown]
# Comparing to real data...

# %%
REAL_data = {
    "CRE": ["nobody", "somebody", "everybody", "redgene", "neurogene", "nobody", "somebody", "everybody", "redgene", "neurogene"],
    "Cell-type": ["brain", "brain", "brain", "brain", "brain", "blood", "blood", "blood", "blood", "blood"],
    "mean": [1, 10, 114, 30, 99, 2, 12, 109, 112, 16]
}

# Creating the dataframe
pd.DataFrame(REAL_data)
# Out:
#          CRE Cell-type  mean
# 0     nobody     brain     1
# 1   somebody     brain    10
# 2  everybody     brain   114
# 3    redgene     brain    30
# 4  neurogene     brain    99
# 5     nobody     blood     2
# 6   somebody     blood    12
# 7  everybody     blood   109
# 8    redgene     blood   112
# 9  neurogene     blood    16

# %% [markdown]
# Works very well.

# %% [markdown]
# # Recapitulation of zero-inflation parameter

# %%
minimal_dropout_design=Z.drop_duplicates()
minimal_dropout_design
# Out:
#       Intercept  C(replicate_ID)[T.rep2]  C(replicate_ID)[T.rep3]
# 0           1.0                      0.0                      0.0
# 4761        1.0                      1.0                      0.0
# 9536        1.0                      0.0                      1.0

# %%
linear_dropout_pred=minimal_dropout_design.to_numpy() @ inflation_betas
linear_dropout_pred
# Out:
# array([1.35542266, 0.02814137, 2.24412758])

# %%
recovered_dropout=1/(1+np.exp(-linear_dropout_pred))
#top to bottom in the matrix are : intercept only (rep1 by process of elim), rep2, rep3
pd.DataFrame({'replicate':["rep1","rep2","rep3"],'dropout':recovered_dropout})
# Out:
#   replicate   dropout
# 0      rep1  0.795015
# 1      rep2  0.507035
# 2      rep3  0.904143

# %% [markdown]
# Compared to real values (.8, .5, .9), that's pretty good!

# %% [markdown]
# # Unsort

# %%
class ZINBFixedAlpha(smdc.ZeroInflatedNegativeBinomialP):
    def __init__(self, endog, exog, exog_infl, fixed_alpha, **kwargs):
        self.fixed_alpha = fixed_alpha  # Save the fixed value of alpha
        super(ZINBFixedAlpha, self).__init__(endog, exog, exog_infl=exog_infl, **kwargs)

    def loglike(self, params):
        """
        Override the log-likelihood so that the overdispersion parameter (alpha)
        is fixed at self.fixed_alpha.

        In the original model, the parameter vector is assumed to be:
            [beta (count params), gamma (inflation params), alpha]

        Here we rebuild the full parameter vector by appending fixed_alpha.
        """
        # Determine the number of parameters in each part:
        k_count = self.exog.shape[1]
        k_infl = self.exog_infl.shape[1] if self.exog_infl is not None else 0

        # Ensure that the incoming params vector has the correct length:
        # It should have length = k_count + k_infl.
        if len(params) != k_count + k_infl:
            raise ValueError("Length of params should be equal to k_count + k_infl.")

        # Build the full parameter vector by appending fixed_alpha:
        full_params = np.r_[params, self.fixed_alpha]

        # Now call the original loglike with the full parameter vector.
        return super(ZINBFixedAlpha, self).loglike(full_params)

    def loglikeobs(self, params):
        """
        Override loglikeobs similarly if needed. This ensures that any calls to the
        per-observation likelihood also use the fixed alpha.
        """
        k_count = self.exog.shape[1]
        k_infl = self.exog_infl.shape[1] if self.exog_infl is not None else 0
        if len(params) != k_count + k_infl+1:
            raise ValueError("Length of params should be equal to k_count + k_infl+1.")
        full_params = np.r_[params, self.fixed_alpha]
        return super(ZINBFixedAlpha, self).loglikeobs(full_params)

# %%
zinb_constrained = ZINBFixedAlpha(y, X, exog_infl=Z,fixed_alpha=0.3)
#zinb_constrained.fix_params()
start_params_reduced= np.full(X.shape[1]+Z.shape[1], 0.1)
zinb_constrained.fit(start_params=start_params_reduced,maxiter=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 4
#       2 #zinb_constrained.fix_params()
#       3 start_params_reduced= np.full(X.shape[1]+Z.shape[1], 0.1)
# ----> 4 zinb_constrained.fit(start_params=start_params_reduced,maxiter=1000)
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/count_model.py:187, in GenericZeroInflated.fit(self, start_params, method, maxiter, full_output, disp, callback, cov_type, cov_kwds, use_t, **kwargs)
#     183 if callback is None:
#     184     # work around perfect separation callback #3895
#     185     callback = lambda *x: x
# --> 187 mlefit = super().fit(start_params=start_params,
#     188                maxiter=maxiter, disp=disp, method=method,
#     189                full_output=full_output, callback=callback,
#     190                **kwargs)
#     192 zipfit = self.result_class(self, mlefit._results)
#     193 result = self.result_class_wrapper(zipfit)
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:1154, in CountModel.fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1151 @Appender(DiscreteModel.fit.__doc__)
#    1152 def fit(self, start_params=None, method='newton', maxiter=35,
#    1153         full_output=1, disp=1, callback=None, **kwargs):
# -> 1154     cntfit = super().fit(start_params=start_params,
#    1155                          method=method,
#    1156                          maxiter=maxiter,
#    1157                          full_output=full_output,
#    1158                          disp=disp,
#    1159                          callback=callback,
#    1160                          **kwargs)
#    1161     discretefit = CountResults(self, cntfit)
#    1162     return CountResultsWrapper(discretefit)
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:243, in DiscreteModel.fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     240 else:
#     241     pass  # TODO: make a function factory to have multiple call-backs
# --> 243 mlefit = super().fit(start_params=start_params,
#     244                      method=method,
#     245                      maxiter=maxiter,
#     246                      full_output=full_output,
#     247                      disp=disp,
#     248                      callback=callback,
#     249                      **kwargs)
#     251 return mlefit
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/base/model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/base/optimizer.py:243, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     240     fit_funcs.update(extra_fit_funcs)
#     242 func = fit_funcs[method]
# --> 243 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     244                      disp=disp, maxiter=maxiter, callback=callback,
#     245                      retall=retall, full_output=full_output,
#     246                      hess=hessian)
#     248 optim_settings = {'optimizer': method, 'start_params': start_params,
#     249                   'maxiter': maxiter, 'full_output': full_output,
#     250                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     251                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     252 optim_settings.update(kwargs)
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/base/optimizer.py:538, in _fit_bfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     536 norm = kwargs.setdefault('norm', np.inf)
#     537 epsilon = kwargs.setdefault('epsilon', 1.4901161193847656e-08)
# --> 538 retvals = optimize.fmin_bfgs(f, start_params, score, args=fargs,
#     539                              gtol=gtol, norm=norm, epsilon=epsilon,
#     540                              maxiter=maxiter, full_output=full_output,
#     541                              disp=disp, retall=retall, callback=callback)
#     542 if full_output:
#     543     if not retall:
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1313, in fmin_bfgs(f, x0, fprime, args, gtol, norm, epsilon, maxiter, full_output, disp, retall, callback, xrtol, c1, c2, hess_inv0)
#    1301 opts = {'gtol': gtol,
#    1302         'norm': norm,
#    1303         'eps': epsilon,
#    (...)
#    1309         'c2': c2,
#    1310         'hess_inv0': hess_inv0}
#    1312 callback = _wrap_callback(callback)
# -> 1313 res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#    1315 if full_output:
#    1316     retlist = (res['x'], res['fun'], res['jac'], res['hess_inv'],
#    1317                res['nfev'], res['njev'], res['status'])
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1393, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, **unknown_options)
#    1390 if maxiter is None:
#    1391     maxiter = len(x0) * 200
# -> 1393 sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1394                               finite_diff_rel_step=finite_diff_rel_step)
#    1396 f = sf.fun
#    1397 myfprime = sf.grad
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/scipy/optimize/_optimize.py:291, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     287     bounds = (-np.inf, np.inf)
#     289 # ScalarFunction caches. Reuse of fun(x) during grad
#     290 # calculation reduces overall function evaluations.
# --> 291 sf = ScalarFunction(fun, x0, args, grad, hess,
#     292                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     294 return sf
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:232, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     225 # Initial gradient evaluation
#     226 self._wrapped_grad, self._ngev = _wrapper_grad(
#     227     grad,
#     228     fun=self._wrapped_fun,
#     229     args=args,
#     230     finite_diff_options=finite_diff_options
#     231 )
# --> 232 self._update_grad()
#     234 # Hessian evaluation
#     235 if callable(hess):
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:307, in ScalarFunction._update_grad(self)
#     305 if self._orig_grad in FD_METHODS:
#     306     self._update_fun()
# --> 307 self.g = self._wrapped_grad(self.x, f0=self.f)
#     308 self.g_updated = True
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:42, in _wrapper_grad.<locals>.wrapped(x, **kwds)
#      39 def wrapped(x, **kwds):
#      40     # kwds present to give function same signature as numdiff variant
#      41     ncalls[0] += 1
# ---> 42     return np.atleast_1d(grad(np.copy(x), *args))
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/base/model.py:545, in LikelihoodModel.fit.<locals>.score(params, *args)
#     544 def score(params, *args):
# --> 545     return -self.score(params, *args) / nobs
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/count_model.py:286, in GenericZeroInflated.score(self, params)
#     285 def score(self, params):
# --> 286     return self.score_obs(params).sum(0)
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/count_model.py:257, in GenericZeroInflated.score_obs(self, params)
#     255 w = self.model_infl.predict(params_infl)
#     256 w = np.clip(w, np.finfo(float).eps, 1 - np.finfo(float).eps)
# --> 257 score_main = self.model_main.score_obs(params_main)
#     258 llf_main = self.model_main.loglikeobs(params_main)
#     259 llf = self.loglikeobs(params)
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:3966, in NegativeBinomialP.score_obs(self, params)
#    3963 p = 2 - self.parameterization
#    3964 y = self.endog
# -> 3966 mu = self.predict(params)
#    3967 mu_p = mu**p
#    3968 a1 = mu_p / alpha
#
# File ~/.conda/envs/biopython/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:4325, in NegativeBinomialP.predict(self, params, exog, exposure, offset, which, y_values)
#    4322 if offset is None:
#    4323     offset = getattr(self, 'offset', 0)
# -> 4325 fitted = np.dot(exog, params[:exog.shape[1]])
#    4326 linpred = fitted + exposure + offset
#    4328 if which == 'mean':
#
# ValueError: shapes (14312,10) and (9,) not aligned: 10 (dim 1) != 9 (dim 0)
