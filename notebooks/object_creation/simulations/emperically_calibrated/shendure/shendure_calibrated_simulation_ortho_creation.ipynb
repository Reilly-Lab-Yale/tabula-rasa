# %% [markdown]
# This notebook fits orthos to all replicates of the shendure-calibrated simulations

# %% [markdown]
# Imports

# %%
import scMPRAforge as scm
from dask_jobqueue import SLURMCluster
from dask.distributed import Client
# Out:
# 2025-10-28 15:16:44.028329: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-28 15:16:44.032455: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /vast/palmer/apps/avx2/software/code-server/4.91.1/lib:/vast/palmer/apps/avx2/software/gettext/0.22.5-GCCcore-13.3.0/lib:/vast/palmer/apps/avx2/software/libiconv/1.17-GCCcore-13.3.0/lib:/vast/palmer/apps/avx2/software/ncurses/6.5-GCCcore-13.3.0/lib:/vast/palmer/apps/avx2/software/libxml2/2.12.7-GCCcore-13.3.0/lib:/vast/palmer/apps/avx2/software/XZ/5.4.5-GCCcore-13.3.0/lib:/vast/palmer/apps/avx2/software/expat/2.6.2-GCCcore-13.3.0/lib:/vast/palmer/apps/avx2/software/cURL/8.7.1-GCCcore-13.3.0/lib:/vast/palmer/apps/avx2/software/OpenSSL/3/lib:/vast/palmer/apps/avx2/software/zlib/1.3.1-GCCcore-13.3.0/lib:/vast/palmer/apps/avx2/software/GCCcore/13.3.0/lib64
# 2025-10-28 15:16:44.032468: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# Autoreload for dev

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Create a nice large cluster. We will need the resorces.

# %%
cluster=SLURMCluster(
    cores=4,#cores per slurm job
    memory="64G",#memory per slurm job
    processes=1,#dask workers per slurm job
    job_extra_directives=["-p ycga", 
        f"--job-name=simclust_worker",
        f"--time=4:00:00",
        f"--output=slave_%j.out"]
)
cluster.scale(jobs=6)
client = Client(cluster,
        timeout=f"{5*60}s",   # Client <-> scheduler timeout 
        heartbeat_interval="20s"  # Worker heartbeat interval
    )

# %% [markdown]
# Load the simulation object

# %%
DATA_ROOT="/gpfs/gibbs/pi/reilly/tabula_data"
simu_obj=scm.de_novo_simulation.load(client,path=f"{DATA_ROOT}/simulated",name="shendure_calibrated_sim_20251008")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /gpfs/gibbs/project/reilly/eng26/.conda/scmpra_tensor/lib/python3.10/site-packages/dask/backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File /gpfs/gibbs/project/reilly/eng26/.conda/scmpra_tensor/lib/python3.10/site-packages/dask/dataframe/io/csv.py:731, in make_reader.<locals>.read(urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     718 def read(
#     719     urlpath,
#     720     blocksize="default",
#    (...)
#     729     **kwargs,
#     730 ):
# --> 731     return read_pandas(
#     732         reader,
#     733         urlpath,
#     734         blocksize=blocksize,
#     735         lineterminator=lineterminator,
#     736         compression=compression,
#     737         sample=sample,
#     738         sample_rows=sample_rows,
#     739         enforce=enforce,
#     740         assume_missing=assume_missing,
#     741         storage_options=storage_options,
#     742         include_path_column=include_path_column,
#     743         **kwargs,
#     744     )
#
# File /gpfs/gibbs/project/reilly/eng26/.conda/scmpra_tensor/lib/python3.10/site-packages/dask/dataframe/io/csv.py:524, in read_pandas(reader, urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     523     sample = blocksize
# --> 524 b_out = read_bytes(
#     525     urlpath,
#     526     delimiter=b_lineterminator,
#     527     blocksize=blocksize,
#     528     sample=sample,
#     529     compression=compression,
#     530     include_path=include_path_column,
#     531     **(storage_options or {}),
#     532 )
#     534 if include_path_column:
#
# File /gpfs/gibbs/project/reilly/eng26/.conda/scmpra_tensor/lib/python3.10/site-packages/dask/bytes/core.py:86, in read_bytes(urlpath, delimiter, not_zero, blocksize, sample, compression, include_path, **kwargs)
#      85 if len(paths) == 0:
# ---> 86     raise OSError("%s resolved to no files" % urlpath)
#      88 if blocksize is not None:
#
# OSError: /gpfs/gibbs/pi/reilly/tabula_data/simulated/shendure_calibrated_sim_20251008/descriptions/0.tsv.gz/* resolved to no files
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 2
#       1 DATA_ROOT="/gpfs/gibbs/pi/reilly/tabula_data"
# ----> 2 simu_obj=scm.de_novo_simulation.load(client,path=f"{DATA_ROOT}/simulated",name="shendure_calibrated_sim_20251008")
#
# File /gpfs/gibbs/project/reilly/eng26/scmpra/bin/tabula-rasa/notebooks/object_creation/simulations/emperically_calibrated/shendure/scMPRAforge/core.py:4412, in de_novo_simulation.load(cls, client, path, name)
#    4406 desc_path = path / "descriptions"
#    4407 for dirpath in sorted(
#    4408         desc_path.glob("*.tsv.gz"),                # these are directories named like "123.tsv.gz/"
#    4409         key=lambda p: int(p.name.replace(".tsv.gz", ""))  # sort by the numeric dir name
#    4410     ):
#    4411     # read all part files inside the directory
# -> 4412     ddf = dd.read_csv(
#    4413         str(dirpath / "*"),                 # e.g., 0.part
#    4414         sep="\t",
#    4415         compression="gzip"
#    4416     )
#    4417     obj.descriptions.append(ddf)
#    4419 #scMPRA
#
# File /gpfs/gibbs/project/reilly/eng26/.conda/scmpra_tensor/lib/python3.10/site-packages/dask/backends.py:151, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     149     raise e
#     150 else:
# --> 151     raise exc from e
#
# OSError: An error occurred while calling the read_csv method registered to the pandas backend.
# Original Message: /gpfs/gibbs/pi/reilly/tabula_data/simulated/shendure_calibrated_sim_20251008/descriptions/0.tsv.gz/* resolved to no files

# %%
#temporary : obj created w/ older version of code, necessitating this. 
simu_obj.orthos=[]

# %% [markdown]
# Fit orthos to all replicates

# %%
simu_obj.create_orthos_for_all_replicates(client)
# Out:
# scMPRAforge: INFO: Dropped 635027 of 4681279 (cell_type, cre_id) combos with fewer than 3 nonzero entries.
# scMPRAforge: INFO: Dropped 635514 of 4684178 (cell_type, cre_id) combos with fewer than 3 nonzero entries.
# scMPRAforge: INFO: Dropped 637026 of 4691445 (cell_type, cre_id) combos with fewer than 3 nonzero entries.
# scMPRAforge: INFO: Dropped 636156 of 4693425 (cell_type, cre_id) combos with fewer than 3 nonzero entries.
# scMPRAforge: INFO: Dropped 636332 of 4694417 (cell_type, cre_id) combos with fewer than 3 nonzero entries.

# %% [markdown]
# Save

# %%
simu_obj.save(path=f"{DATA_ROOT}/simulated",name="shendure_calibrated_sim_with_orthos_20251008")

# %% [markdown]
# Shut down the cluster

# %%
client.close()
cluster.close()
