# %% [markdown]
# A better version of `power_shendure_vs_minp.ipynb` with a more representative distribution of positive and negative effects. Specifically, we will be using the real values, plus 50%
#
# We will also reduce computational burden by producing half-orthos.
