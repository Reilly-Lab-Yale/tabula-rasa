# %%
import scMPRAforge as scm
# %load_ext autoreload
# %autoreload 2
# Out:
# 2026-02-13 15:15:24.656841: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
from dask.distributed import Client, LocalCluster
cluster=LocalCluster()
client=Client(cluster)

# %%
path="/home/mcn26/project_pi_skr2/shared/tabula_data/seelig"
name="ortho_seelig_v2"
data_root="/gpfs/gibbs/pi/reilly/tabula_data"
primordial=scm.ortho.load(client,path,name)

# %%
seelig_bounds=scm.Bounds.from_ortho(primordial)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 seelig_bounds=scm.Bounds.from_ortho(primordial)
#
# File /nfs/roberts/project/pi_skr2/mcn26/tabula-rasa/notebooks/object_creation/abstract_bounds/scMPRAforge/core.py:941, in Bounds.from_ortho(cls, inp, preferred)
#     937 ret.theta=np.mean([ret.by_cell_type_theta,ret.by_cre_theta])
#     939 ## Parameters from training data ##
#     940 # transfection, as proxied by number of MPRA barcodes detected per cell
# --> 941 ret.transfection_model=inp.training_data.describe_transfection()
#     943 # library model
#     944 ret.library_model=inp.training_data.describe_library()
#
# File /nfs/roberts/project/pi_skr2/mcn26/tabula-rasa/notebooks/object_creation/abstract_bounds/scMPRAforge/core.py:1089, in scMPRA_data.describe_transfection(self)
#    1079 """
# ...
