# %%
import scMPRAforge as scm

# %%
# %load_ext autoreload
# %autoreload 2

# %%
data_root="/gpfs/gibbs/pi/reilly/tabula_data"
path="/gpfs/gibbs/pi/reilly/tabula_data/cohen"
name="ortho_primordial"

cohen=scm.scMPRA_data.from_parquet(f"{path}/retina_single_counting_u6.scmpra")

cohen.set_negative_controls(["wt_1","wt_2"])
cohen.set_reference_cell("Rod")
cohen.ortho_filter()
# Out:
# scMPRAforge: INFO: Dropped 0 of 456 (cell_type, cre_id) combos with fewer than 3 nonzero entries.

# %%
cohen.data
# Out:
#                   cell_bc  rep_id                     cre_id  \
# 0        AAACCCAAGACAAGCC       1            combo_Mute_crx1
# 1        AAACCCAAGACAAGCC       1            combo_Mute_crx1
# 2        AAACCCAAGACAAGCC       1            combo_Mute_crx1
# 3        AAACCCAAGACAAGCC       1            combo_Mute_crx1
# 4        AAACCCAAGACAAGCC       1            combo_Mute_crx1
# ...                   ...     ...                        ...
# 7351464  TTTGTTGTCGTTCAGA       2  tail_conserve6_493_to_498
# 7351465  TTTGTTGTCGTTCAGA       2  tail_conserve6_498_to_503
# 7351466  TTTGTTGTCGTTCAGA       2  tail_conserve6_498_to_503
# 7351467  TTTGTTGTCGTTCAGA       2                  reference
# 7351468  TTTGTTGTCGTTCAGA       2                  reference
#
#                           mpra_bc  umis_mpra_bc  umis_transfection_bc  \
# 0        ACCTGTATGGAATGAGCGGGTCCA           1.0                   0.0
# 1        ATTATAAAAGATACTCATGAGTCT           1.0                   0.0
# 2        CGGTTGATTTCCGGTTTACCAGAT           1.0                   0.0
# 3        GTGTTTAATCGTAGACGCGACGAT           1.0                   0.0
# 4        GTTACCGAGGGCTGCAGTGTAGAG           1.0                   0.0
# ...                           ...           ...                   ...
# 7351464  GGCTGAAACCACGTTCCTAATCTC           1.0                   0.0
# 7351465  CAACAGTTACCCTGCATACCTCGG           1.0                   0.0
# 7351466  TTGTAAGTCAGAATCTCATACCCC           1.0                   0.0
# 7351467  TATTTGCCTATTCTTACATCACCT           1.0                   0.0
# 7351468  TTTCGTTTAAGTGCCGTAAGTGCG           1.0                   0.0
#
#          cell_type            cre_id_original
# 0        reference            combo_Mute_crx1
# 1        reference            combo_Mute_crx1
# 2        reference            combo_Mute_crx1
# 3        reference            combo_Mute_crx1
# 4        reference            combo_Mute_crx1
# ...            ...                        ...
# 7351464  reference  tail_conserve6_493_to_498
# 7351465  reference  tail_conserve6_498_to_503
# 7351466  reference  tail_conserve6_498_to_503
# 7351467  reference                       wt_1
# 7351468  reference                       wt_1
#
# [7351469 rows x 8 columns]

# %%
"""
data=data.data
    levels=data[split].unique()

    mats_futures = {
        t: client.submit(
            _smart_matrix,
            data=data[data[split]==t],
            split=split
        )
        for t in levels
    }
"""
data=cohen.data[cohen.data["cell_type"]=="reference"]
mats=scm.smart_matrix(data=data,split="cell_type")

# %%
#mats["nb_regressors"]=mats["nb_regressors"].sparse.to_dense()

# %%
#import faulthandler, sys
#logf = open("tracebacks.log", "w")
#faulthandler.enable(logf)  # also prints on unhandled signals
# dump stacks every 60 s; repeat forever
#faulthandler.dump_traceback_later(60, repeat=True, file=logf, exit=False)


import faulthandler, threading, time, os

def start_rotating_stacks(interval=60, prefix="tracebacks"):
    faulthandler.enable()
    def _worker():
        while True:
            ts = time.strftime("%Y%m%d-%H%M%S")
            path = f"{prefix}_{ts}.log"
            with open(path, "w") as f:
                print(f"STACK DUMP @ {ts} (pid={os.getpid()})", file=f)
                import threading
                for t in threading.enumerate():
                    nid = getattr(t, "native_id", None)
                    print(f"  thread name={t.name!r} ident={t.ident} native_id={nid}", file=f)
                print("-"*80, file=f)
                faulthandler.dump_traceback(file=f, all_threads=True)
            time.sleep(interval)
    threading.Thread(target=_worker, name="faulthandler-rotator", daemon=True).start()
start_rotating_stacks()
"""
tzinb_futures = {
        t: client.submit(
                _tensorzinb_fit,
                mats_futures[t],
                t
            )
        for t in levels
    }
"""
model=scm.tensorzinb_fit(mats,"reference")
# Out:
# Metal device set to: Apple M4 Pro
#
# systemMemory: 24.00 GB
# maxCacheSize: 8.00 GB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 37
#      26 start_rotating_stacks()
#      27 """
#      28 tzinb_futures = {
#      29         t: client.submit(
#    (...)
#      35     }
#      36 """
# ---> 37 model=scm.tensorzinb_fit(mats,"reference")
#
# File ~/tabula-rasa/notebooks/object_creation/orthos/scMPRAforge/core.py:1266, in tensorzinb_fit(matricies, name)
#    1265 def tensorzinb_fit(matricies,name):
# -> 1266     return _tensorzinb_fit(matricies,name)
#
# File ~/tabula-rasa/notebooks/object_creation/orthos/scMPRAforge/core.py:1277, in _tensorzinb_fit(matricies, name)
#    1269 """
#    1270 Takes matricies & produces a single tensorzinb model
#    1271 """
#    1272 zinbo = TensorZINB(endog=matricies["regressand"]["umis_mpra_bc"].to_numpy().squeeze(),
#    1273                 exog=matricies["nb_regressors"].to_numpy(),
#    1274                 exog_infl=matricies["zi_regressors"].to_numpy())
# -> 1277 result = zinbo.fit(init_method="nb")
#    1279 del zinbo
#    1281 return result
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/tensorzinb/tensorzinb.py:268, in TensorZINB.fit(self, init_weights, init_method, device_type, device_name, return_history, epochs, learning_rate, num_epoch_skip, is_early_stop, is_reduce_lr, min_delta_early_stop, patience_early_stop, factor_reduce_lr, patience_reduce_lr, min_lr, reset_keras_session, **kwargs)
#     266         init_weights = self._poisson_init()
#     267     elif init_method == "nb":
# --> 268         init_weights = self._nb_init()
#     270 # use distinct names to retrieve weights from layers
#     271 weight_keys = ["x_mu", "z_mu", "x_pi", "z_pi", "theta"]
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/tensorzinb/tensorzinb.py:595, in TensorZINB._nb_init(self, infl_prob_max, intercept_var_th)
#     587 def _nb_init(self, infl_prob_max=0.99, intercept_var_th=1e-3):
#     588     nb_mod = TensorZINB(
#     589         self.endog,
#     590         self.exog,
#    (...)
#     593         nb_only=True,
#     594     )
# --> 595     nb_res = nb_mod.fit(init_method="poi")
#     596     weights = nb_res["weights"]
#     598     if self._no_exog_infl:
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/tensorzinb/tensorzinb.py:373, in TensorZINB.fit(self, init_weights, init_method, device_type, device_name, return_history, epochs, learning_rate, num_epoch_skip, is_early_stop, is_reduce_lr, min_delta_early_stop, patience_early_stop, factor_reduce_lr, patience_reduce_lr, min_lr, reset_keras_session, **kwargs)
#     371 try:
#     372     start_time = time.time()
# --> 373     losses = model.fit(
#     374         [
#     375             self.exog,
#     376             self.exog_c,
#     377             self.exog_infl,
#     378             self.exog_infl_c,
#     379             np.ones((num_sample, 1)),
#     380         ],
#     381         [self.endog],
#     382         callbacks=callbacks,
#     383         batch_size=num_sample,
#     384         epochs=epochs,
#     385         verbose=0,
#     386     )
#     387     cpu_time = time.time() - start_time
#     388     break
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/keras/engine/training_v1.py:776, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     773 self._check_call_args('fit')
#     775 func = self._select_training_loop(x)
# --> 776 return func.fit(
#     777     self,
#     778     x=x,
#     779     y=y,
#     780     batch_size=batch_size,
#     781     epochs=epochs,
#     782     verbose=verbose,
#     783     callbacks=callbacks,
#     784     validation_split=validation_split,
#     785     validation_data=validation_data,
#     786     shuffle=shuffle,
#     787     class_weight=class_weight,
#     788     sample_weight=sample_weight,
#     789     initial_epoch=initial_epoch,
#     790     steps_per_epoch=steps_per_epoch,
#     791     validation_steps=validation_steps,
#     792     validation_freq=validation_freq,
#     793     max_queue_size=max_queue_size,
#     794     workers=workers,
#     795     use_multiprocessing=use_multiprocessing)
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/keras/engine/training_arrays_v1.py:641, in ArrayLikeTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     637     raise ValueError('`validation_steps` should not be specified if '
#     638                      '`validation_data` is None.')
#     639   val_x, val_y, val_sample_weights = None, None, None
# --> 641 return fit_loop(
#     642     model,
#     643     inputs=x,
#     644     targets=y,
#     645     sample_weights=sample_weights,
#     646     batch_size=batch_size,
#     647     epochs=epochs,
#     648     verbose=verbose,
#     649     callbacks=callbacks,
#     650     val_inputs=val_x,
#     651     val_targets=val_y,
#     652     val_sample_weights=val_sample_weights,
#     653     shuffle=shuffle,
#     654     initial_epoch=initial_epoch,
#     655     steps_per_epoch=steps_per_epoch,
#     656     validation_steps=validation_steps,
#     657     validation_freq=validation_freq,
#     658     steps_name='steps_per_epoch')
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/keras/engine/training_arrays_v1.py:377, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     374 callbacks._call_batch_hook(mode, 'begin', batch_index, batch_logs)
#     376 # Get outputs.
# --> 377 batch_outs = f(ins_batch)
#     378 if not isinstance(batch_outs, list):
#     379   batch_outs = [batch_outs]
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/keras/backend.py:4269, in GraphExecutionFunction.__call__(self, inputs)
#    4266     # We need to do array conversion and type casting at this level, since
#    4267     # `callable_fn` only supports exact matches.
#    4268     tensor_type = tf.as_dtype(tensor.dtype)
# -> 4269     array_vals.append(np.asarray(value,
#    4270                                  dtype=tensor_type.as_numpy_dtype))
#    4272 if self.feed_dict:
#    4273   for key in sorted(self.feed_dict.keys()):
#
# KeyboardInterrupt:

# %%
model
# Out:
# {'llf_total': -8621654.230280649,
#  'llfs': array([-8621654.23028065]),
#  'aic_total': 17243542.460561298,
#  'aics': array([17243542.4605613]),
#  'df_model_total': 117,
#  'df': 117,
#  'weights': {'x_mu': array([[ 0.18049324],
#          [ 0.028015  ],
#          [-0.54401433],
#          [-0.19119652],
#          [-0.03164005],
#          [-0.01554258],
#          [-0.04608611],
#          [-0.00444012],
#          [ 0.01401729],
#          [-0.25623703],
#          [-0.03848658],
#          [ 0.01064393],
#          [ 0.0220978 ],
#          [-0.4414297 ],
#          [-0.0432388 ],
#          [ 0.00467352],
#          [ 0.01736145],
#          [-0.01697542],
#          [-0.04304417],
#          [-0.00875928],
#          [ 0.00837715],
#          [-0.41268328],
#          [-0.00964242],
#          [-0.00212638],
#          [-0.11239314],
#          [ 0.00761595],
#          [ 0.02225263],
#          [ 0.03941045],
#          [ 0.00480314],
#          [ 0.00995729],
#          [ 0.00778865],
#          [-0.0142555 ],
#          [-0.09976934],
#          [ 0.00171296],
#          [ 0.0053463 ],
#          [-0.01423442],
#          [-0.02081797],
#          [ 0.04057425],
#          [-0.04542348],
#          [-0.01034064],
#          [ 0.01970903],
#          [ 0.03702262],
#          [-0.04188579],
#          [ 0.0178074 ],
#          [-0.00955858],
#          [ 0.00081169],
#          [ 0.00155544],
#          [ 0.0210553 ],
#          [-0.00764953],
#          [-0.0345273 ],
#          [-0.01501912],
#          [-0.11323854],
#          [-0.11791631],
#          [-0.10598953],
#          [ 0.09920968],
#          [-0.01927565],
#          [-0.02017484],
#          [ 0.025316  ],
#          [-0.05818485],
#          [ 0.00867409],
#          [-0.06303255],
#          [-0.01308144],
#          [-0.0141947 ],
#          [-0.00913637],
#          [ 0.01439069],
#          [ 0.01627919],
#          [ 0.02702495],
#          [-0.00531342],
#          [ 0.00744428],
#          [-0.00613373],
#          [-0.00780153],
#          [ 0.01402443],
#          [-0.01485603],
#          [ 0.02421155],
#          [ 0.01851671],
#          [-0.0020352 ],
#          [ 0.00870385],
#          [ 0.02502031],
#          [ 0.03493042],
#          [ 0.02200594],
#          [-0.00608606],
#          [ 0.0196167 ],
#          [-0.02560749],
#          [-0.00720961],
#          [-0.01308349],
#          [-0.04164337],
#          [-0.01232605],
#          [-0.0414276 ],
#          [-0.19082649],
#          [ 0.01844736],
#          [ 0.01841441],
#          [ 0.02002249],
#          [-0.01646801],
#          [ 0.04250329],
#          [ 0.01707707],
#          [ 0.04001233],
#          [ 0.02306473],
#          [ 0.01929369],
#          [ 0.00304479],
#          [-0.00765624],
#          [ 0.03564712],
#          [ 0.0221758 ],
#          [ 0.01752611],
#          [ 0.00788493],
#          [ 0.0132002 ],
#          [ 0.0054304 ],
#          [-0.01215855],
#          [ 0.00268321],
#          [-0.00749815],
#          [ 0.00973368],
#          [-0.00814216],
#          [ 0.00750315],
#          [ 0.01507159],
#          [ 0.00991311]], dtype=float32),
#   'x_pi': array([[-11.33516 ],
#          [-10.218624]], dtype=float32),
#   'theta': array([[2.1662853]], dtype=float32)},
#  'cpu_time': 9840.720577001572,
#  'num_sample': 6579970,
#  'epochs': 4337}
