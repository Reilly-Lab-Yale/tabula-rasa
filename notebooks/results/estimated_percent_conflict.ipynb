# %% [markdown]
# Numbers taken from INFO messages in abstract_bounds
#
# COHEN: scMPRAforge: INFO: Computed a total of 7991.940630106255 estimated collision events, out of a total of 6837023.940630106, or 0.11689209661257542%
# SHENDURE: scMPRAforge: INFO: Computed a total of 414.7088384600356 estimated collision events, out of a total of 781874.70883846, or 0.05304031883524153%
# SEELIG: (not done)

# %%
percent_collision={"Cohen":0.11689209661257542,"Shendure":0.05304031883524153}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

collision_df = (
    pd.DataFrame(
        {"method": list(percent_collision.keys()), "collision_rate": list(percent_collision.values())}
    )
    .sort_values("collision_rate", ascending=False)
 )

sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(4, 3))
sns.barplot(data=collision_df, x="method", y="collision_rate", ax=ax, color="#4C78A8")
ax.set_xlabel("")
ax.set_ylabel("Collision rate (fraction of total transfection events)")
ax.set_title("Estimated collision rate")
ax.set_ylim(0, max(collision_df["collision_rate"].max() * 1.15, 0.01))
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f%%", labels=[f"{v*100:.1f}%" for v in collision_df['collision_rate']])
fig.tight_layout()
out_svg = "./estimated_percent_conflict_collision_rate.svg"
fig.savefig(out_svg, format="svg", bbox_inches="tight")
out_svg
# Out:
# './estimated_percent_conflict_collision_rate.svg'
