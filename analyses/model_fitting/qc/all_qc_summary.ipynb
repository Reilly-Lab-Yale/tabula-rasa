# %% [markdown]
# # QC summary -- all phantom orthos
#
# Consolidated view of QC plots across all datasets and model variants.
# Plots are referenced in-place (no duplication). Worst-case by_cre plots omitted.
#
# **Canonical models** (used for simulations / downstream analysis):
# - Shendure: obs NB
# - Cohen: obsingle NB
# - Seelig: CM NB
# - Takeshi: obs NB

# %%
from pathlib import Path
from IPython.display import display, SVG, Markdown

QC_ROOT = Path(".")  # notebook lives in qc/

# All ortho dirs, grouped by dataset
DATASETS = {
    "Shendure": [
        ("obs NB (canonical)", "canonical_shendure_obs_nb_phantom"),
        ("obs ZINB", "shendure_obs_zinb_phantom"),
        ("CM NB", "shendure_cm_nb_phantom"),
        ("CM ZINB", "shendure_cm_zinb_phantom"),
    ],
    "Cohen": [
        ("obsingle NB (canonical)", "cohen_obsingle_nb_phantom"),
        ("obsingle ZINB", "cohen_obsingle_zinb_phantom"),
        ("obs NB", "cohen_obs_nb_phantom_20260401"),
        ("obs ZINB", "canonical_cohen_obs_zinb_phantom_20260401"),
        ("CM NB", "cohen_cm_nb_phantom_20260401"),
        ("CM ZINB", "cohen_cm_zinb_phantom_20260401"),
    ],
    "Seelig": [
        ("CM NB (canonical)", "canonical_seelig_cm_nb_phantom"),
        ("CM ZINB", "seelig_cm_zinb_phantom"),
    ],
    "Takeshi": [
        ("obs NB (canonical)", "canonical_takeshi_obs_nb_phantom"),
        ("obs ZINB", "takeshi_obs_zinb_phantom"),
        ("CM NB", "takeshi_cm_nb_phantom"),
        ("CM ZINB", "takeshi_cm_zinb_phantom"),
    ],
}

# Plot types to show (in order), excluding worst
PLOTS = [
    "r_values",
    "mu_vs_mean_by_cell_type",
    "theta_distributions",
    "zi_by_cell_type",
    "r_vs_missing",
]

# %%
for dataset, orthos in DATASETS.items():
    display(Markdown(f"---\n# {dataset}"))
    for label, dirname in orthos:
        display(Markdown(f"## {label}\n`{dirname}`"))
        # Show summary.txt snippet
        summary_path = QC_ROOT / dirname / "summary.txt"
        if summary_path.exists():
            txt = summary_path.read_text()
            # Just the convergence + mu range + pearson header lines
            lines = txt.strip().split("\n")
            # Find convergence through end of pearson r section header
            keep = []
            in_section = False
            for line in lines:
                if "Convergence" in line or "Mu range" in line or "Pearson r" in line:
                    in_section = True
                if in_section:
                    keep.append(line)
                    if line.strip().startswith("by_cre: mean r="):
                        keep.append("")  # stop after by_cre summary line
                        in_section = False
            if keep:
                display(Markdown("```\n" + "\n".join(keep) + "\n```"))
        # Show plots
        for plot_name in PLOTS:
            svg_path = QC_ROOT / dirname / "plots" / f"{plot_name}.svg"
            if svg_path.exists():
                display(Markdown(f"### {plot_name.replace('_', ' ').title()}"))
                display(SVG(filename=str(svg_path)))
# Out:
# ---
# # Shendure
# ## obs NB (canonical)
# `canonical_shendure_obs_nb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 10/10 converged
#   by_cre: 208/208 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0034  max=329.4717  median=0.0705
#   by_cre: min=0.0034  max=329.3849  median=0.0705
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0
#   by_cre: mean r=nan  min=nan  max=nan  n(r<0.8)=0
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ## obs ZINB
# `shendure_obs_zinb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 10/10 converged
#   by_cre: 208/208 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0035  max=344.3855  median=0.0716
#   by_cre: min=0.0049  max=371.3200  median=0.1288
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0
#   by_cre: mean r=nan  min=nan  max=nan  n(r<0.8)=2
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### Zi By Cell Type
# ## CM NB
# `shendure_cm_nb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 10/10 converged
#   by_cre: 208/208 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0000  max=0.7658  median=0.0000
#   by_cre: min=0.0000  max=0.7685  median=0.0000
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0
#   by_cre: mean r=0.998  min=0.938  max=1.000  n(r<0.8)=0
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ## CM ZINB
# `shendure_cm_zinb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 10/10 converged
#   by_cre: 208/208 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0000  max=1.9157  median=0.0001
#   by_cre: min=0.0000  max=1.8953  median=0.0001
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0
#   by_cre: mean r=0.993  min=0.849  max=1.000  n(r<0.8)=0
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### Zi By Cell Type
# ---
# # Cohen
# ## obsingle NB (canonical)
# `cohen_obsingle_nb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 4/4 converged
#   by_cre: 114/114 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0193  max=1.3918  median=0.8832
#   by_cre: min=0.0239  max=1.3919  median=0.8850
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=0.646  min=0.588  max=0.719  n(r<0.8)=4  n_nan_r=0
#     NaN anti-levels dropped before regression: 9/461 across all models
#     Low-r levels (r < 0.8):
#       r=0.588  reference
#       r=0.616  Interneuron
#       r=0.660  Mueller Glia
#       r=0.719  Bipolar
#   by_cre: mean r=0.394  min=-0.995  max=0.996  n(r<0.8)=86  n_nan_r=1
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### R Vs Missing
# ## obsingle ZINB
# `cohen_obsingle_zinb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 4/4 converged
#   by_cre: 114/114 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0008  max=1.4143  median=0.8860
#   by_cre: min=0.0003  max=1.4071  median=0.8884
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=0.648  min=0.589  max=0.721  n(r<0.8)=4  n_nan_r=0
#     NaN anti-levels dropped before regression: 9/461 across all models
#     Low-r levels (r < 0.8):
#       r=0.589  reference
#       r=0.617  Interneuron
#       r=0.667  Mueller Glia
#       r=0.721  Bipolar
#   by_cre: mean r=0.397  min=-0.994  max=0.996  n(r<0.8)=85  n_nan_r=1
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### Zi By Cell Type
# ### R Vs Missing
# ## obs NB
# `cohen_obs_nb_phantom_20260401`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 4/4 converged
#   by_cre: 114/114 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0001  max=0.0149  median=0.0008
#   by_cre: min=0.0000  max=0.2750  median=0.0008
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=nan  min=nan  max=nan  n(r<0.8)=3
#     Low-r levels (r < 0.8):
#       r=-0.039  Bipolar
#       r=0.016  reference
#       r=0.222  Interneuron
#   by_cre: mean r=nan  min=nan  max=nan  n(r<0.8)=90
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### R Vs Missing
# ## obs ZINB
# `canonical_cohen_obs_zinb_phantom_20260401`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 4/4 converged
#   by_cre: 114/114 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0001  max=0.0163  median=0.0014
#   by_cre: min=0.0001  max=0.5126  median=0.0015
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=nan  min=nan  max=nan  n(r<0.8)=3
#     Low-r levels (r < 0.8):
#       r=-0.009  Bipolar
#       r=0.027  reference
#       r=0.353  Interneuron
#   by_cre: mean r=nan  min=nan  max=nan  n(r<0.8)=90
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### Zi By Cell Type
# ### R Vs Missing
# ## CM NB
# `cohen_cm_nb_phantom_20260401`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 4/4 converged
#   by_cre: 114/114 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0000  max=0.0007  median=0.0001
#   by_cre: min=0.0000  max=0.0015  median=0.0001
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=nan  min=nan  max=nan  n(r<0.8)=1
#     Low-r levels (r < 0.8):
#       r=0.706  reference
#   by_cre: mean r=nan  min=nan  max=nan  n(r<0.8)=78
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### R Vs Missing
# ## CM ZINB
# `cohen_cm_zinb_phantom_20260401`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 4/4 converged
#   by_cre: 114/114 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0000  max=0.0015  median=0.0002
#   by_cre: min=0.0000  max=0.0052  median=0.0001
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=nan  min=nan  max=nan  n(r<0.8)=1
#     Low-r levels (r < 0.8):
#       r=0.557  reference
#   by_cre: mean r=nan  min=nan  max=nan  n(r<0.8)=78
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### Zi By Cell Type
# ### R Vs Missing
# ---
# # Seelig
# ## CM NB (canonical)
# `canonical_seelig_cm_nb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 2/2 converged
#   by_cre: 1344/1344 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0000  max=0.8556  median=0.0056
#   by_cre: min=0.0000  max=0.8591  median=0.0056
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0
#   by_cre: mean r=0.999  min=-1.000  max=1.000  n(r<0.8)=1
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ## CM ZINB
# `seelig_cm_zinb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 2/2 converged
#   by_cre: 1344/1344 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0000  max=0.8625  median=0.0056
#   by_cre: min=0.0000  max=0.8605  median=0.0056
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0
#   by_cre: mean r=0.999  min=-1.000  max=1.000  n(r<0.8)=1
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### Zi By Cell Type
# ---
# # Takeshi
# ## obs NB (canonical)
# `canonical_takeshi_obs_nb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 3/3 converged
#   by_cre: 150/150 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0016  max=1.5793  median=0.0371
#   by_cre: min=0.0016  max=1.5837  median=0.0372
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0  n_nan_r=0
#     NaN anti-levels dropped before regression: 0/380 across all models
#   by_cre: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0  n_nan_r=25
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ## obs ZINB
# `takeshi_obs_zinb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 3/3 converged
#   by_cre: 150/150 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0016  max=1.5951  median=0.0375
#   by_cre: min=0.0016  max=1.5975  median=0.0376
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0  n_nan_r=0
#     NaN anti-levels dropped before regression: 0/380 across all models
#   by_cre: mean r=1.000  min=1.000  max=1.000  n(r<0.8)=0  n_nan_r=25
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### Zi By Cell Type
# ## CM NB
# `takeshi_cm_nb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 3/3 converged
#   by_cre: 150/150 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0000  max=0.0106  median=0.0001
#   by_cre: min=0.0000  max=0.0112  median=0.0001
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=0.962  min=0.954  max=0.976  n(r<0.8)=0  n_nan_r=0
#     NaN anti-levels dropped before regression: 70/450 across all models
#   by_cre: mean r=0.944  min=-1.000  max=1.000  n(r<0.8)=3  n_nan_r=25
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### R Vs Missing
# ## CM ZINB
# `takeshi_cm_zinb_phantom`
# ```
# -- Convergence ---------------------------------------------------------
#
#   by_cell_type: 3/3 converged
#   by_cre: 150/150 converged
#
# -- Mu range (NB mean estimate) -----------------------------------------
#
#   by_cell_type: min=0.0000  max=0.0083  median=0.0001
#   by_cre: min=0.0000  max=0.0114  median=0.0001
#
# -- Pearson r (mu vs mean UMI) ------------------------------------------
#
#   by_cell_type: mean r=0.873  min=0.806  max=0.920  n(r<0.8)=0  n_nan_r=0
#     NaN anti-levels dropped before regression: 70/450 across all models
#   by_cre: mean r=0.944  min=-1.000  max=1.000  n(r<0.8)=3  n_nan_r=25
#
# ```
# ### R Values
# ### Mu Vs Mean By Cell Type
# ### Theta Distributions
# ### Zi By Cell Type
# ### R Vs Missing
