# %% [markdown]
# This notebook produces & saves an scMPRA data object of the cohen retina scmpra experiment, using the ==Single counting U6 approach==. See below for details.

# %% [markdown]
# # Setup

# %%
import scMPRAforge as scm
import pandas as pd
import itertools

# %% [markdown]
# Load data

# %%
HEADWATER="/gpfs/gibbs/pi/reilly/tabula_data/cohen"
#raw_mpra=pd.read_csv(f"{HEADWATER}/read_wise_mpra_retina.tsv",sep="\t")
raw_u6=pd.read_csv(f"{HEADWATER}/unjoined/u6.tsv",sep="\t")

# %%
raw_u6
# Out:
#          reads           umi       pBC  rep_id           cell_bc cell_type  \
# 0           34  AAGGCGAGAGAG  ATGGAATG       1  AAACCCATCGCCGAGT       Rod
# 1           32  ACGCATCTCTTG  CGGTGAGA       1  AAACCCAGTAATCAGA       Rod
# 2           32  ACTCTACCATAA  AATCTCCA       1  AAACCCAGTAATCAGA       Rod
# 3            1  AGCCTCACAACC  ATGGAATG       1  AAACCCAGTAATCAGA       Rod
# 4           22  AGCCTCACAACG  ATGGAATG       1  AAACCCAGTAATCAGA       Rod
# ...        ...           ...       ...     ...               ...       ...
# 3640103      1  GCAACTCACCAT  CCTGAGTT       2  TTTGTTGAGCTGCCAC       Rod
# 3640104      1  GTCTGAGGATCC  AGTGATTC       2  TTTGTTGAGCTGCCAC       Rod
# 3640105     26  GTGACTTTCTGT  CGCGTTAC       2  TTTGTTGAGCTGCCAC       Rod
# 3640106      5  TTACAAGTCGCA  ATGGAATG       2  TTTGTTGAGCTGCCAC       Rod
# 3640107      2  TTGCCCGATACT  AGTGATTC       2  TTTGTTGAGCTGCCAC       Rod
#
#                             cre_id
# 0        tail_conserve6_483_to_488
# 1              combo_Q50_crx4_crx2
# 2        ebox_gcagctgg_to_gcagctag
# 3        tail_conserve6_483_to_488
# 4        tail_conserve6_483_to_488
# ...                            ...
# 3640103       combo_Mute_crx3_crx1
# 3640104  tail_conserve4_428_to_433
# 3640105        combo_Q50_crx5_crx2
# 3640106  tail_conserve6_483_to_488
# 3640107  tail_conserve4_428_to_433
#
# [3640108 rows x 7 columns]

# %%
mpra_dat=scm.scMPRA_data.from_tsv(f"{HEADWATER}/unjoined/read_wise_mpra_retina.tsv")

# %%
mpra_dat.read_wise_to_umi_wise()

# %%
mpra_dat.data
# Out:
#                   cell_bc  rep_id                     cre_id cell_type  \
# 0        AAACCCAAGACAAGCC       1            combo_Mute_crx1       Rod
# 1        AAACCCAAGACAAGCC       1            combo_Mute_crx1       Rod
# 2        AAACCCAAGACAAGCC       1            combo_Mute_crx1       Rod
# 3        AAACCCAAGACAAGCC       1            combo_Mute_crx1       Rod
# 4        AAACCCAAGACAAGCC       1            combo_Mute_crx1       Rod
# ...                   ...     ...                        ...       ...
# 7275510  TTTGTTGTCGTTCAGA       2  tail_conserve6_493_to_498       Rod
# 7275511  TTTGTTGTCGTTCAGA       2  tail_conserve6_498_to_503       Rod
# 7275512  TTTGTTGTCGTTCAGA       2  tail_conserve6_498_to_503       Rod
# 7275513  TTTGTTGTCGTTCAGA       2                       wt_1       Rod
# 7275514  TTTGTTGTCGTTCAGA       2                       wt_1       Rod
#
#                           mpra_bc  umis
# 0        ACCTGTATGGAATGAGCGGGTCCA     1
# 1        ATTATAAAAGATACTCATGAGTCT     1
# 2        CGGTTGATTTCCGGTTTACCAGAT     1
# 3        GTGTTTAATCGTAGACGCGACGAT     1
# 4        GTTACCGAGGGCTGCAGTGTAGAG     1
# ...                           ...   ...
# 7275510  GGCTGAAACCACGTTCCTAATCTC     1
# 7275511  CAACAGTTACCCTGCATACCTCGG     1
# 7275512  TTGTAAGTCAGAATCTCATACCCC     1
# 7275513  TATTTGCCTATTCTTACATCACCT     1
# 7275514  TTTCGTTTAAGTGCCGTAAGTGCG     1
#
# [7275515 rows x 6 columns]

# %% [markdown]
# # Rationale
#
# How exactly do we want to handle integration of regular MPRA & tfection reporter?
#
# So the thing is that the u6 data does not correspond directly to the MPRA bc. Instead, it corresponds to the CRE (pBC)...
#
# Here's one approach: "Utilize U6 approach"
# - For each replicate
#   - For all combinations of cell barcode, CRE
#     - If the CRE has at least one MPRA bc in that cell, move on. U6 info can tell us nothing about missing zeroes
#     - If the CRE does **not** have at least one MPRA bc in that cell, check U6
#       - If U6 says the CRE is present in that cell, add zeroes for all MPRAbc for that CRE in that cell
#       - If the U6 does NOT say the CRE is present in that cell, do NOT add a zero.
#
# The advantage of this approach is that it lets us use the U6 data to add in some true zeroes.
#
# Disadvantage : A single transfected MPRA barcode in a given cell prevents U6 information from adding true zeroes to any other barcodes, causing undersetimation of zeroes.
#
# Here's another approach: "Simple zero padding approach"
# - For each replicate
#   - For all combinations of cell barcode, MPRA barcode
#     - if the combination is not present, add it as a zero
#     - if the combination is present, continue.
#
# The basic *problem* with this approach is that it over-estimates zeroes due to incomplete transfection.
#
# The advantages of this approach are that it is very simple and can be applied to datasets with NO transfection reporter.
#
# Note that the "Utilize U6 approach" can be considered a subset of the "simple zero padding approach". If we take "simple zero padding approach" and then simply remove those zeroes which are not supported by U6, we get "Utilize U6 approach". ~~For that reason, I'm going to briefly run both.~~
#
# ~~Actually....~~
# ~~there is perhaps a rather less intense way to get at the "utilize U6 approach" as listing all combos to start is maybe too intense... Here's an alternative approach~~
# - ~~`rbc_map` = Create a map of CRE->rBC from the observed data. Replicate-agnostic.~~
# - ~~missing = Anti-merge U6 with normal MPRA data to get all (CRE, cell bc, repid) combos which are NOT present in regular MPRA data~~
# - ~~zero df = left merge missing, map on CRE id~~
# - ~~final df = original MPRA df concat with zero df~~
#
# Ok, here's another option. In [the original paper](https://www.nature.com/articles/s41588-022-01278-7), activity is calculated counting each case of U6 but no MPRA as one zero.
# =="Single-counting U6 approach"==
# - u6_umi = summarize u6 umi counts
# - padded = outer join of u6 & mpra data on cell_bc, rep_id, cre_id
# - Then pad missing values

# %% [markdown]
# ## Note: barcode-level U6 zero expansion (March 2026 fix)
#
# The original approach inserts one dummy row per (cell, CRE) when U6 detects a CRE but no MPRA barcodes are observed. The correct expansion is one zero per known barcode for that (rep, CRE), matching the granularity of non-zero observations. See regen_scmpra_object.py for the standalone fix. If re-running this notebook, replace the fillna("dummy") block with a merge against bc_map (all known barcodes per (rep, CRE)) to expand right_only rows to barcode level.

# %% [markdown]
# # Processing

# %%
u6_umi=raw_u6
u6_umi=u6_umi.drop(columns=["reads", "pBC"])
u6_umi=u6_umi.groupby([i for i in u6_umi.columns if i !="umi"]).aggregate(umis_transfection_bc= ('umi', 'nunique')).reset_index()
u6_umi
# Out:
#         rep_id           cell_bc    cell_type                         cre_id  \
# 0            1  AAACCCAAGACAAGCC          Rod           combo_Mute_crx5_crx2
# 1            1  AAACCCAAGACAAGCC          Rod                 combo_Q50_crx2
# 2            1  AAACCCAAGACAAGCC          Rod      ebox_gcagctgg_to_gcagcggg
# 3            1  AAACCCAAGACAAGCC          Rod      tail_conserve2_188_to_193
# 4            1  AAACCCAAGACAAGCC          Rod      tail_conserve3_240_to_245
# ...        ...               ...          ...                            ...
# 159186       2  TTTGTTGTCGTTAGAC  Interneuron      tail_conserve3_215_to_220
# 159187       2  TTTGTTGTCGTTCAGA          Rod                combo_Mute_crx2
# 159188       2  TTTGTTGTCGTTCAGA          Rod  swap_crx2_to_gggcttag_reverse
# 159189       2  TTTGTTGTCGTTCAGA          Rod      tail_conserve2_193_to_198
# 159190       2  TTTGTTGTCGTTCAGA          Rod      tail_conserve6_478_to_483
#
#         umis_transfection_bc
# 0                          1
# 1                          2
# 2                          1
# 3                          2
# 4                          1
# ...                      ...
# 159186                     1
# 159187                    73
# 159188                     2
# 159189                     2
# 159190                     2
#
# [159191 rows x 5 columns]

# %%
padded=mpra_dat.data.merge(u6_umi,how="outer",indicator=True,on=["rep_id","cell_bc","cre_id"],validate="many_to_one")
#many to one since multiple rBC
padded
# Out:
#                   cell_bc  rep_id                     cre_id cell_type_x  \
# 0        AAACCCAAGACAAGCC       1            combo_Mute_crx1         Rod
# 1        AAACCCAAGACAAGCC       1            combo_Mute_crx1         Rod
# 2        AAACCCAAGACAAGCC       1            combo_Mute_crx1         Rod
# 3        AAACCCAAGACAAGCC       1            combo_Mute_crx1         Rod
# 4        AAACCCAAGACAAGCC       1            combo_Mute_crx1         Rod
# ...                   ...     ...                        ...         ...
# 7351464  TTTGTTGTCGTTCAGA       2  tail_conserve6_493_to_498         Rod
# 7351465  TTTGTTGTCGTTCAGA       2  tail_conserve6_498_to_503         Rod
# 7351466  TTTGTTGTCGTTCAGA       2  tail_conserve6_498_to_503         Rod
# 7351467  TTTGTTGTCGTTCAGA       2                       wt_1         Rod
# 7351468  TTTGTTGTCGTTCAGA       2                       wt_1         Rod
#
#                           mpra_bc  umis cell_type_y  umis_transfection_bc  \
# 0        ACCTGTATGGAATGAGCGGGTCCA   1.0         NaN                   NaN
# 1        ATTATAAAAGATACTCATGAGTCT   1.0         NaN                   NaN
# 2        CGGTTGATTTCCGGTTTACCAGAT   1.0         NaN                   NaN
# 3        GTGTTTAATCGTAGACGCGACGAT   1.0         NaN                   NaN
# 4        GTTACCGAGGGCTGCAGTGTAGAG   1.0         NaN                   NaN
# ...                           ...   ...         ...                   ...
# 7351464  GGCTGAAACCACGTTCCTAATCTC   1.0         NaN                   NaN
# 7351465  CAACAGTTACCCTGCATACCTCGG   1.0         NaN                   NaN
# 7351466  TTGTAAGTCAGAATCTCATACCCC   1.0         NaN                   NaN
# 7351467  TATTTGCCTATTCTTACATCACCT   1.0         NaN                   NaN
# 7351468  TTTCGTTTAAGTGCCGTAAGTGCG   1.0         NaN                   NaN
#
#             _merge
# 0        left_only
# 1        left_only
# 2        left_only
# 3        left_only
# 4        left_only
# ...            ...
# 7351464  left_only
# 7351465  left_only
# 7351466  left_only
# 7351467  left_only
# 7351468  left_only
#
# [7351469 rows x 9 columns]

# %%
padded["_merge"].value_counts()
# Out:
# _merge
# left_only     4445565
# both          2829950
# right_only      75954
# Name: count, dtype: int64

# %% [markdown]
# left_only means mpra but no u6, right_only means u6 but no MPRA, both means both. So we are only adding 75954 zeroes.
#
# Let us fill in the missing values...

# %%
filled=padded

# %% [markdown]
# Let's fill in the cell-type information. First, make sure there are no conflicts.

# %%
conflicts = filled[
    filled["cell_type_x"].notna() & 
    filled["cell_type_y"].notna() & 
    (filled["cell_type_x"] != filled["cell_type_y"])
]
if not conflicts.empty:
    raise ValueError(f"Conflicting cell types found:\n{conflicts}")

# %% [markdown]
# Perfect. Now let's fill...

# %%
filled["cell_type"] = filled["cell_type_x"].combine_first(filled["cell_type_y"])
filled["umis"]=filled["umis"].fillna(0)
filled["umis_transfection_bc"]=filled["umis_transfection_bc"].fillna(0)
filled["mpra_bc"]=filled["mpra_bc"].fillna("dummy")

# %% [markdown]
# drop useless columns

# %%
filled=filled.drop(columns=['cell_type_x', 'cell_type_y','_merge'])

# %%
filled=filled.rename({'umis':'umis_mpra_bc'},axis=1)

# %% [markdown]
# Check if there are any NA...

# %%
assert not filled.isnull().values.any()

# %% [markdown]
# Ok perfect! now let's dump this dataframe to disc...

# %%
filled.to_csv(f"{HEADWATER}/retina_single_counting_u6.tsv",sep="\t",index=False)

# %% [markdown]
# And make & save a scmpra object...

# %%
finalized_object=scm.scMPRA_data.from_tsv(f"{HEADWATER}/retina_single_counting_u6.tsv")

# %%
finalized_object.to_parquet(f"{HEADWATER}/retina_single_counting_u6.scmpra")
