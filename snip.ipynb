# %%
import scMPRAforge as scm
import pickle

# %%
data_root="/gpfs/gibbs/pi/reilly/tabula_data/shendure/intercept_model_temp"
with open(data_root+"/by_cell_type.pkl","rb") as f:
    by_ct=pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# CommClosedError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/comm/core.py:291, in connect(addr, timeout, deserialize, handshake_overrides, **connection_args)
#     290 try:
# --> 291     comm = await asyncio.wait_for(
#     292         connector.connect(loc, deserialize=deserialize, **connection_args),
#     293         timeout=min(intermediate_cap, time_left()),
#     294     )
#     295     break
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/asyncio/tasks.py:445, in wait_for(fut, timeout)
#     444 if fut.done():
# --> 445     return fut.result()
#     446 else:
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/comm/tcp.py:511, in BaseTCPConnector.connect(self, address, deserialize, **connection_args)
#     509 except StreamClosedError as e:
#     510     # The socket connect() call failed
# --> 511     convert_stream_closed_error(self, e)
#     512 except SSLCertVerificationError as err:
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/comm/tcp.py:142, in convert_stream_closed_error(obj, exc)
#     141             raise FatalCommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}")
# --> 142     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
#     143 else:
#
# CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x3795737f0>: ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 3
#       1 data_root="/gpfs/gibbs/pi/reilly/tabula_data/shendure/intercept_model_temp"
#       2 with open(data_root+"/by_cell_type.pkl","rb") as f:
# ----> 3     by_ct=pickle.load(f)
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:469, in Future.__setstate__(self, state)
#     467     c = Client.current(allow_global=False)
#     468 except ValueError:
# --> 469     c = get_client(address)
#     470 self.__init__(key, c)
#     471 c._send_to_scheduler(
#     472     {
#     473         "op": "update-graph",
#    (...)
#     477     }
#     478 )
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/worker.py:2791, in get_client(address, timeout, resolve_address)
#    2789     return client
#    2790 elif address:
# -> 2791     return Client(address, timeout=timeout)
#    2792 else:
#    2793     raise ValueError("No global client found and no address provided")
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:988, in Client.__init__(self, address, loop, timeout, set_as_default, scheduler_file, security, asynchronous, name, heartbeat_interval, serializers, deserializers, extensions, direct_to_workers, connection_limit, **kwargs)
#     985 preload_argv = dask.config.get("distributed.client.preload-argv")
#     986 self.preloads = preloading.process_preloads(self, preload, preload_argv)
# --> 988 self.start(timeout=timeout)
#     989 Client._instances.add(self)
#     991 from distributed.recreate_tasks import ReplayTaskClient
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:1185, in Client.start(self, **kwargs)
#    1183     self._started = asyncio.ensure_future(self._start(**kwargs))
#    1184 else:
# -> 1185     sync(self.loop, self._start, **kwargs)
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/utils.py:405, in sync(loop, func, callback_timeout, *args, **kwargs)
#     403 if error:
#     404     typ, exc, tb = error
# --> 405     raise exc.with_traceback(tb)
#     406 else:
#     407     return result
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/utils.py:378, in sync.<locals>.f()
#     376         future = asyncio.wait_for(future, callback_timeout)
#     377     future = asyncio.ensure_future(future)
# --> 378     result = yield future
#     379 except Exception:
#     380     error = sys.exc_info()
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/tornado/gen.py:769, in Runner.run(self)
#     767 try:
#     768     try:
# --> 769         value = future.result()
#     770     except Exception as e:
#     771         # Save the exception for later. It's important that
#     772         # gen.throw() not be called inside this try/except block
#     773         # because that makes sys.exc_info behave unexpectedly.
#     774         exc: Optional[Exception] = e
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:1265, in Client._start(self, timeout, **kwargs)
#    1262 self.scheduler_comm = None
#    1264 try:
# -> 1265     await self._ensure_connected(timeout=timeout)
#    1266 except (OSError, ImportError):
#    1267     await self._close()
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:1328, in Client._ensure_connected(self, timeout)
#    1325 self._connecting_to_scheduler = True
#    1327 try:
# -> 1328     comm = await connect(
#    1329         self.scheduler.address, timeout=timeout, **self.connection_args
#    1330     )
#    1331     comm.name = "Client->Scheduler"
#    1332     if timeout is not None:
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/comm/core.py:317, in connect(addr, timeout, deserialize, handshake_overrides, **connection_args)
#     315         await asyncio.sleep(backoff)
#     316 else:
# --> 317     raise OSError(
#     318         f"Timed out trying to connect to {addr} after {timeout} s"
#     319     ) from active_exception
#     321 local_info = {
#     322     **comm.handshake_info(),
#     323     **(handshake_overrides or {}),
#     324 }
#     325 try:
#     326     # This would be better, but connections leak if worker is closed quickly
#     327     # write, handshake = await asyncio.gather(comm.write(local_info), comm.read())
#
# OSError: Timed out trying to connect to tcp://127.0.0.1:50828 after 30 s

# %%
by_ct

# %%
from dask.distributed import Client, LocalCluster
cluster=LocalCluster()
client = Client(cluster)

# %%
foobar=scm.ortho.load(client,
                      data_root,
                      "intercept_model_temp")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# CommClosedError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/comm/core.py:291, in connect(addr, timeout, deserialize, handshake_overrides, **connection_args)
#     290 try:
# --> 291     comm = await asyncio.wait_for(
#     292         connector.connect(loc, deserialize=deserialize, **connection_args),
#     293         timeout=min(intermediate_cap, time_left()),
#     294     )
#     295     break
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/asyncio/tasks.py:445, in wait_for(fut, timeout)
#     444 if fut.done():
# --> 445     return fut.result()
#     446 else:
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/comm/tcp.py:511, in BaseTCPConnector.connect(self, address, deserialize, **connection_args)
#     509 except StreamClosedError as e:
#     510     # The socket connect() call failed
# --> 511     convert_stream_closed_error(self, e)
#     512 except SSLCertVerificationError as err:
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/comm/tcp.py:142, in convert_stream_closed_error(obj, exc)
#     141             raise FatalCommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}")
# --> 142     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
#     143 else:
#
# CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x337158fd0>: ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 2
#       1 data_root="/gpfs/gibbs/pi/reilly/tabula_data/shendure"
# ----> 2 foobar=scm.ortho.load(client,
#       3                       data_root,
#       4                       "intercept_model_temp")
#
# File ~/tabula-rasa/scMPRAforge/core.py:708, in ortho.load(cls, client, path, name)
#     704         return client.submit(lambda x: x, pickle.load(f))
#     706 ret=cls()
# --> 708 ret.by_cre=_undump("by_cre.pkl")
#     709 ret.by_cre_parameters=_undump("by_cre_parameters.pkl")
#     710 ret.by_cell_type=_undump("by_cell_type.pkl")
#
# File ~/tabula-rasa/scMPRAforge/core.py:704, in ortho.load.<locals>._undump(filename)
#     700 """
#     701 Loads from a filename & re-wraps as a future
#     702 """
#     703 with open(full_path/filename,"rb") as f:
# --> 704     return client.submit(lambda x: x, pickle.load(f))
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:469, in Future.__setstate__(self, state)
#     467     c = Client.current(allow_global=False)
#     468 except ValueError:
# --> 469     c = get_client(address)
#     470 self.__init__(key, c)
#     471 c._send_to_scheduler(
#     472     {
#     473         "op": "update-graph",
#    (...)
#     477     }
#     478 )
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/worker.py:2791, in get_client(address, timeout, resolve_address)
#    2789     return client
#    2790 elif address:
# -> 2791     return Client(address, timeout=timeout)
#    2792 else:
#    2793     raise ValueError("No global client found and no address provided")
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:988, in Client.__init__(self, address, loop, timeout, set_as_default, scheduler_file, security, asynchronous, name, heartbeat_interval, serializers, deserializers, extensions, direct_to_workers, connection_limit, **kwargs)
#     985 preload_argv = dask.config.get("distributed.client.preload-argv")
#     986 self.preloads = preloading.process_preloads(self, preload, preload_argv)
# --> 988 self.start(timeout=timeout)
#     989 Client._instances.add(self)
#     991 from distributed.recreate_tasks import ReplayTaskClient
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:1185, in Client.start(self, **kwargs)
#    1183     self._started = asyncio.ensure_future(self._start(**kwargs))
#    1184 else:
# -> 1185     sync(self.loop, self._start, **kwargs)
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/utils.py:405, in sync(loop, func, callback_timeout, *args, **kwargs)
#     403 if error:
#     404     typ, exc, tb = error
# --> 405     raise exc.with_traceback(tb)
#     406 else:
#     407     return result
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/utils.py:378, in sync.<locals>.f()
#     376         future = asyncio.wait_for(future, callback_timeout)
#     377     future = asyncio.ensure_future(future)
# --> 378     result = yield future
#     379 except Exception:
#     380     error = sys.exc_info()
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/tornado/gen.py:769, in Runner.run(self)
#     767 try:
#     768     try:
# --> 769         value = future.result()
#     770     except Exception as e:
#     771         # Save the exception for later. It's important that
#     772         # gen.throw() not be called inside this try/except block
#     773         # because that makes sys.exc_info behave unexpectedly.
#     774         exc: Optional[Exception] = e
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:1265, in Client._start(self, timeout, **kwargs)
#    1262 self.scheduler_comm = None
#    1264 try:
# -> 1265     await self._ensure_connected(timeout=timeout)
#    1266 except (OSError, ImportError):
#    1267     await self._close()
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/client.py:1328, in Client._ensure_connected(self, timeout)
#    1325 self._connecting_to_scheduler = True
#    1327 try:
# -> 1328     comm = await connect(
#    1329         self.scheduler.address, timeout=timeout, **self.connection_args
#    1330     )
#    1331     comm.name = "Client->Scheduler"
#    1332     if timeout is not None:
#
# File /opt/anaconda3/envs/env_tensorzinb/lib/python3.10/site-packages/distributed/comm/core.py:317, in connect(addr, timeout, deserialize, handshake_overrides, **connection_args)
#     315         await asyncio.sleep(backoff)
#     316 else:
# --> 317     raise OSError(
#     318         f"Timed out trying to connect to {addr} after {timeout} s"
#     319     ) from active_exception
#     321 local_info = {
#     322     **comm.handshake_info(),
#     323     **(handshake_overrides or {}),
#     324 }
#     325 try:
#     326     # This would be better, but connections leak if worker is closed quickly
#     327     # write, handshake = await asyncio.gather(comm.write(local_info), comm.read())
#
# OSError: Timed out trying to connect to tcp://127.0.0.1:50828 after 30 s

# %%
foobar
